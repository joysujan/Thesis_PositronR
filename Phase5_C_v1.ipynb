# %%
# Phase C full prep: maximize item inclusion, resolve haven_labelled, keep all DASS/BRS candidates
library(dplyr)
library(readr)
library(haven)
library(stringr)
library(purrr)

dir.create("outputs/PhaseC_prep", recursive = TRUE, showWarnings = FALSE)

# 1) Load item-level base (should be from Phase A prep, not raw SPSS)
items0 <- readRDS("outputs/PhaseA_prep/items_ordered_wide.rds")

# Convert any haven_labelled variables to factors
items <- haven::as_factor(items0, only_labelled = TRUE)

# 2) All DASS and BRS items from your codebook
d_items <- c("dQ1S","dQ2A","dQ3D","dQ4A","dQ5D","dQ6S","dQ7A","dQ8S","dQ9A",
             "dQ10D","dQ11S","dQ12S","dQ13D","dQ14S","dQ15A","dQ16D","dQ17D","dQ18S","dQ19A","dQ20A","dQ21D")
r_items <- c("rQ1","rQ3","rQ5","rQ2_r","rQ4_r","rQ6_r")

# 3) Load all flagged/annotated EFA outputs to decide DASS set inclusively
efa_flags <- readr::read_csv("outputs/PhaseA_A3/DASS_item_flags_annotated.csv", show_col_types = FALSE)

# Include all items that pass at least one filter or aren't flagged as clearly poor, e.g.,
dass_cand <-
  efa_flags %>%
  filter(is.na(keep_EFA) | keep_EFA | abs(primary_loading) >= 0.4) %>%
  pull(item) %>%
  unique()

# Double-check to recover any that were not flagged but are in original DASS set:
dass_cand <- unique(c(dass_cand, d_items))

# For BRS, use all 6
brs_cand <- r_items

# 4) Prepare group flags and response matrix
grp_vars <- c("gender","academic_year")
resp_df <- items %>% select(any_of(c("id", grp_vars, d_items, r_items)))

# Ensure grouping variables are plain factors
for (g in intersect(grp_vars, names(resp_df))) {
  if (inherits(resp_df[[g]], "haven_labelled")) {
    resp_df[[g]] <- haven::as_factor(resp_df[[g]])
  }
  if (!is.factor(resp_df[[g]])) {
    resp_df[[g]] <- factor(as.character(resp_df[[g]]))
  }
}

# Convert (ordered factor, labelled, or character) to numeric, original scale
to_num <- function(x){
  if (is.factor(x)) {
    v <- as.character(x)
    suppressWarnings(as.numeric(v))
  } else if (inherits(x, "haven_labelled")) {
    as.numeric(as.character(haven::as_factor(x)))
  } else {
    as.numeric(x)
  }
}

resp_dass <- resp_df %>% select(any_of(dass_cand))
resp_brs  <- resp_df %>% select(any_of(brs_cand))

resp_dass_num <- as.data.frame(lapply(resp_dass, to_num))
resp_brs_num  <- as.data.frame(lapply(resp_brs,  to_num))

# Sanity check level ranges
summarize_levels <- function(df){
  data.frame(
    item = names(df),
    min  = sapply(df, function(x) suppressWarnings(min(x, na.rm = TRUE))),
    max  = sapply(df, function(x) suppressWarnings(max(x, na.rm = TRUE))),
    nNA  = sapply(df, function(x) sum(is.na(x)))
  )
}
lvl_dass <- summarize_levels(resp_dass_num)
lvl_brs  <- summarize_levels(resp_brs_num)
readr::write_csv(lvl_dass, "outputs/PhaseC_prep/check_levels_DASS_candidates.csv")
readr::write_csv(lvl_brs,  "outputs/PhaseC_prep/check_levels_BRS_candidates.csv")

# 5) Assemble GRM-ready file
phaseC_inputs <- list(
  resp_dass_num = resp_dass_num,
  resp_brs_num  = resp_brs_num,
  group_gender  = resp_df$gender,
  group_year    = resp_df$academic_year,
  id            = resp_df$id,
  dass_cand     = dass_cand,
  brs_cand      = brs_cand
)
saveRDS(phaseC_inputs, "outputs/PhaseC_prep/phaseC_inputs.rds")

# 6) Save summary log for record/documentation
summary_lines <- c(
  "Phase C prep (EXPANDED):",
  paste("Included DASS items (n =", length(dass_cand), "):", paste(dass_cand, collapse = ", ")),
  paste("Included BRS items (n = 6):", paste(brs_cand, collapse = ", ")),
  "- Items retain original scoring (DASS 0-3, BRS 1-5).",
  "- Group variables gender and academic_year are plain factors.",
  "- No pre-emptive removal after EFA/network; all candidates retained for IRT and DIF model selection."
)
writeLines(summary_lines, "outputs/PhaseC_prep/summary_phaseC_expanded.txt")
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
library(mirt)
library(dplyr)
library(readr)

dir.create("outputs/PhaseC_C1", recursive = TRUE, showWarnings = FALSE)

inp <- readRDS("outputs/PhaseC_prep/phaseC_inputs.rds")
dat <- as.data.frame(inp$resp_dass_num)     # all DASS candidates retained
# Out:
# Loading required package: stats4
# Loading required package: lattice

# %%
set.seed(20250911)
mod_uni <- mirt(dat, 1, itemtype = "graded", method = "EM", SE = TRUE, technical = list(NCYCLES = 1000))
saveRDS(mod_uni, "outputs/PhaseC_C1/mod_uni.rds")
# Out:
# Iteration: 33, Log-Lik: -21718.224, Max-Change: 0.00008
#
# Calculating information matrix...

# %%
par_uni <- coef(mod_uni, IRTpars = TRUE, simplify = TRUE)$items
pars <- as.data.frame(par_uni) %>% tibble::rownames_to_column("item")

# Threshold ordering flag
thr_cols <- grep("^b\\.", names(pars), value = TRUE)
pars$thr_ordered <- apply(pars[, thr_cols, drop = FALSE], 1, function(v) all(diff(as.numeric(v)) > 0))

# Simple keep flags (do not drop yet; just annotate)
pars <- pars %>%
  mutate(a_ok = a >= 1.0,
         note = paste0("a_ok=", a_ok, "; thr_ord=", thr_ordered))
readr::write_csv(pars, "outputs/PhaseC_C1/item_parameters.csv")

# %%
# Works with missing: X2, G2, infit, PV_Q1 (per docs); S_X2 not allowed with NAs
fit_ok <- itemfit(mod_uni, fit_stats = c("X2","infit"), na.rm = TRUE)
readr::write_csv(as.data.frame(fit_ok), "outputs/PhaseC_C1/itemfit_X2_infit.csv")

# Optional (complete cases only) to compute S_X2
dat_cc <- dat[stats::complete.cases(dat), , drop = FALSE]
if (nrow(dat_cc) > 0) {
  mod_cc <- mirt(dat_cc, 1, itemtype = "graded", method = "EM")
  fit_SX2 <- itemfit(mod_cc, fit_stats = "S_X2")
  readr::write_csv(as.data.frame(fit_SX2), "outputs/PhaseC_C1/itemfit_SX2_complete_cases.csv")
}
# Out:
# Sample size after row-wise response data removal: 669
# Iteration: 35, Log-Lik: -17334.185, Max-Change: 0.00009

# %%
Q3 <- residuals(mod_uni, type = "Q3")
readr::write_csv(as.data.frame(Q3), "outputs/PhaseC_C1/Q3_matrix.csv")

# Top absolute Q3 pairs
top_q3 <- function(Q){
  nm <- colnames(Q); out <- list()
  for (i in seq_len(ncol(Q)-1)) for (j in (i+1):ncol(Q)) out[[length(out)+1]] <- c(nm[i], nm[j], Q[i,j])
  df <- as.data.frame(do.call(rbind, out), stringsAsFactors = FALSE)
  names(df) <- c("item_i","item_j","Q3"); df$Q3 <- as.numeric(df$Q3)
  df %>% arrange(desc(abs(Q3)))
}
q3_tbl <- top_q3(Q3)
readr::write_csv(q3_tbl %>% head(50), "outputs/PhaseC_C1/top_Q3_pairs.csv")
# Out:
# Q3 summary statistics:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  -0.241  -0.096  -0.046  -0.038   0.017   0.290
#
#         dQ2A   dQ3D   dQ4A   dQ5D   dQ6S   dQ7A   dQ8S  dQ10D  dQ13D  dQ14S
# dQ2A   1.000  0.072  0.102  0.108  0.032  0.105  0.072 -0.049 -0.068  0.143
# dQ3D   0.072  1.000  0.000  0.042 -0.073 -0.073 -0.118  0.064 -0.049  0.001
# dQ4A   0.102  0.000  1.000  0.046 -0.053  0.049  0.007 -0.064 -0.126 -0.114
# dQ5D   0.108  0.042  0.046  1.000  0.018  0.014  0.048 -0.112 -0.042  0.033
# dQ6S   0.032 -0.073 -0.053  0.018  1.000  0.041  0.003 -0.139  0.002  0.028
# dQ7A   0.105 -0.073  0.049  0.014  0.041  1.000  0.126 -0.120 -0.081  0.080
# dQ8S   0.072 -0.118  0.007  0.048  0.003  0.126  1.000 -0.188 -0.079  0.068
# dQ10D -0.049  0.064 -0.064 -0.112 -0.139 -0.120 -0.188  1.000 -0.078 -0.065
# dQ13D -0.068 -0.049 -0.126 -0.042  0.002 -0.081 -0.079 -0.078  1.000 -0.012
# dQ14S  0.143  0.001 -0.114  0.033  0.028  0.080  0.068 -0.065 -0.012  1.000
# ...

# %%
Theta <- seq(-3, 3, 0.1)
TI <- testinfo(mod_uni, Theta)
rel <- TI / (TI + 1)
info_tbl <- data.frame(theta = Theta, test_info = TI, reliability = rel)
readr::write_csv(info_tbl, "outputs/PhaseC_C1/test_information_curve.csv")

# %%
library(mirt)
library(dplyr)
library(readr)
library(tidyr)
library(purrr)
library(stringr)

dir.create("outputs/PhaseC_C2", recursive = TRUE, showWarnings = FALSE)

# Load inputs and C1 model
inp      <- readRDS("outputs/PhaseC_prep/phaseC_inputs.rds")
dat_full <- as.data.frame(inp$resp_dass_num)
mod_uni  <- readRDS("outputs/PhaseC_C1/mod_uni.rds")

# Config
MIN_A              <- 1.00
Q3_ABS_THRESH      <- 0.25
FIT_P_THRESH       <- 0.01
THETA_BAND         <- c(0.5, 2.0)
MIN_KEEP_PER_DOMAIN<- 2
MAX_AUTODROP       <- 4
APPLY_DECISIONS    <- FALSE

stopifnot(!is.null(mod_uni), isTRUE(mod_uni@OptimInfo$converged))  # require converged model [3]

# 1) Item parameters and threshold ordering [3]
par_items <- coef(mod_uni, IRTpars = TRUE, simplify = TRUE)$items %>%
  as.data.frame() %>% tibble::rownames_to_column("item")

thr_cols <- grep("^b\\.", names(par_items), value = TRUE)
par_items <- par_items %>%
  mutate(thr_ordered = if (length(thr_cols) == 0) TRUE else
           apply(select(., all_of(thr_cols)), 1, function(v) all(diff(as.numeric(v)) > 0)),
         a_ok = !is.na(a) & a >= MIN_A)

# 2) Item fit that works with missing data (avoid S_X2) [4]
fit_tbl <- tryCatch({
  out <- as.data.frame(itemfit(mod_uni, fit_stats = c("X2","infit"), na.rm = TRUE))
  out$item <- rownames(out); rownames(out) <- NULL
  # mirt versions differ: ensure we have 'p' for X2 p-value
  if (!"p" %in% names(out) && "p.X2" %in% names(out)) out$p <- out[["p.X2"]]
  out
}, error = function(e) tibble(item = par_items$item, X2 = NA, p = NA, infit = NA, z.infit = NA))

# 3) Local dependence (Q3 residuals) [5]
Q3 <- tryCatch(residuals(mod_uni, type = "Q3"), error = function(e) NULL)
if (!is.null(Q3)) {
  q3_pairs <- tibble(
    item_i = rep(colnames(Q3), each = ncol(Q3)),
    item_j = rep(colnames(Q3), times = ncol(Q3)),
    Q3     = as.vector(Q3)
  ) %>% filter(item_i != item_j)
  readr::write_csv(q3_pairs %>% arrange(desc(abs(Q3))) %>% head(100),
                   "outputs/PhaseC_C2/top_Q3_pairs.csv")
  q3_max <- q3_pairs %>%
    group_by(item = item_i) %>%
    summarize(max_absQ3 = max(abs(Q3), na.rm = TRUE), .groups = "drop")
} else {
  q3_max <- tibble(item = par_items$item, max_absQ3 = NA_real_)
}

# 4) Per-item information via testinfo (robust) [1][2]
Theta <- seq(-3, 3, by = 0.1)
band  <- Theta >= THETA_BAND[6] & Theta <= THETA_BAND[7]
item_names <- colnames(dat_full); n_items <- length(item_names)

item_info <- purrr::map_dfr(seq_len(n_items), function(k){
  inf_k <- testinfo(mod_uni, Theta, which.items = k)  # info for item k [1][2]
  tibble(item = item_names[k],
         mean_info_band = mean(inf_k[band], na.rm = TRUE),
         peak_info      = max(inf_k, na.rm = TRUE))
})

# 5) Test information and reliability [1][2]
TI  <- testinfo(mod_uni, Theta)
REL <- TI/(TI + 1)
readr::write_csv(data.frame(theta = Theta, test_info = TI, reliability = REL),
                 "outputs/PhaseC_C2/test_information_curve.csv")

# 6) Merge diagnostics and propose conservative actions [3]
infer_domain <- function(s){
  case_when(
    str_detect(s, "D$") ~ "Dep",
    str_detect(s, "A$") ~ "Anx",
    str_detect(s, "S$") ~ "Str",
    TRUE ~ NA_character_
  )
}

diag_full <- par_items %>%
  left_join(select(fit_tbl, item, X2, p, infit, z.infit), by = "item") %>%
  left_join(q3_max, by = "item") %>%
  left_join(item_info, by = "item") %>%
  mutate(
    domain       = infer_domain(item),
    fit_flag     = (!is.na(p) & p < FIT_P_THRESH) | (!is.na(infit) & abs(infit - 1) > 0.2),
    q3_flag      = !is.na(max_absQ3) & max_absQ3 >= Q3_ABS_THRESH,
    low_a_flag   = !is.na(a) & a < MIN_A,
    low_inf_flag = !is.na(mean_info_band) & mean_info_band < quantile(mean_info_band, 0.25, na.rm = TRUE),
    bad_thr_flag = isFALSE(thr_ordered),
    issue_count  = rowSums(cbind(bad_thr_flag, fit_flag, q3_flag, low_a_flag, low_inf_flag), na.rm = TRUE),
    ProposedAction = case_when(
      bad_thr_flag ~ "DROP",
      issue_count >= 2 ~ "DROP",
      TRUE ~ "KEEP"
    ),
    Reason = case_when(
      bad_thr_flag ~ "threshold_disorder",
      issue_count >= 2 ~ "multi_issues",
      TRUE ~ "ok_or_borderline"
    )
  )

# Domain minimum constraint [3]
enforce_domain_min <- function(df){
  out <- df
  for (dom in c("Dep","Anx","Str")) {
    sub <- out %>% filter(domain == dom)
    keep_now <- sum(sub$ProposedAction != "DROP", na.rm = TRUE)
    need <- MIN_KEEP_PER_DOMAIN - keep_now
    if (need > 0) {
      to_revert <- sub %>% filter(ProposedAction == "DROP") %>%
        arrange(issue_count, desc(mean_info_band)) %>% head(need) %>% pull(item)
      out$ProposedAction[out$item %in% to_revert] <- "KEEP"
      out$Reason[out$item %in% to_revert] <- paste0("revert_to_meet_domain_min(", dom, ")")
    }
  }
  out
}
diag_full <- enforce_domain_min(diag_full)

# Cap auto-drops [3]
drop_idx <- which(diag_full$ProposedAction == "DROP")
if (length(drop_idx) > MAX_AUTODROP) {
  keep_back <- drop_idx[order(diag_full$issue_count[drop_idx], -diag_full$mean_info_band[drop_idx])][(MAX_AUTODROP + 1):length(drop_idx)]
  diag_full$ProposedAction[keep_back] <- "KEEP"
  diag_full$Reason[keep_back] <- "revert_to_respect_max_autodrop"
}

# Decisions table (manual edit encouraged)
dec_path <- "outputs/PhaseC_C2/decisions_items.csv"
readr::write_csv(
  diag_full %>%
    select(item, domain, a, starts_with("b."), thr_ordered, X2, p, infit, z.infit,
           max_absQ3, mean_info_band, peak_info, issue_count, ProposedAction, Reason),
  dec_path
)
message("Edit ProposedAction in: ", dec_path)

# 7) Jackknife Δ information using testinfo (robust) [1][2]
Theta_band <- Theta[band]
base_info  <- testinfo(mod_uni, Theta_band)
jack_tbl <- purrr::map_dfr(seq_len(n_items), function(k){
  info_minus_k <- testinfo(mod_uni, Theta_band, which.items = setdiff(seq_len(n_items), k))
  tibble(item = item_names[k], delta_info_band = mean(base_info - info_minus_k, na.rm = TRUE))
})
readr::write_csv(jack_tbl, "outputs/PhaseC_C2/jackknife_delta_info.csv")

# 8) Optional: apply decisions and refit reduced model [3][1]
APPLY_DECISIONS <- FALSE  # set TRUE after editing decisions_items.csv
if (APPLY_DECISIONS) {
  user_dec <- readr::read_csv(dec_path, show_col_types = FALSE)
  final_keep <- user_dec %>% filter(toupper(ProposedAction) == "KEEP") %>% pull(item) %>% intersect(colnames(dat_full))
  if (length(final_keep) < sum(MIN_KEEP_PER_DOMAIN)) stop("Too few items after decisions; revise your table.")
  dat_red <- dat_full[, final_keep, drop = FALSE]

  set.seed(20250911)
  mod_red <- mirt(dat_red, 1, itemtype = "graded", method = "EM", SE = TRUE, technical = list(NCYCLES = 1000))
  saveRDS(mod_red, "outputs/PhaseC_C2/mod_reduced.rds")

  TI_red  <- testinfo(mod_red, Theta)
  REL_red <- TI_red/(TI_red + 1)
  readr::write_csv(data.frame(theta = Theta, test_info = TI_red, reliability = REL_red),
                   "outputs/PhaseC_C2/test_information_curve_reduced.csv")

  fit_red <- tryCatch({
    out <- as.data.frame(itemfit(mod_red, fit_stats = c("X2","infit"), na.rm = TRUE))
    out$item <- rownames(out); rownames(out) <- NULL; out
  }, error = function(e) NULL)
  if (!is.null(fit_red)) readr::write_csv(fit_red, "outputs/PhaseC_C2/itemfit_reduced_X2_infit.csv")

  Q3_red <- tryCatch(residuals(mod_red, type = "Q3"), error = function(e) NULL)
  if (!is.null(Q3_red)) readr::write_csv(as.data.frame(Q3_red), "outputs/PhaseC_C2/Q3_matrix_reduced.csv")

  message("Reduced model refit complete with ", length(final_keep), " items.")
}
# Out:
# Sample size after row-wise response data removal: 669
# Q3 summary statistics:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  -0.241  -0.096  -0.046  -0.038   0.017   0.290
#
#         dQ2A   dQ3D   dQ4A   dQ5D   dQ6S   dQ7A   dQ8S  dQ10D  dQ13D  dQ14S
# dQ2A   1.000  0.072  0.102  0.108  0.032  0.105  0.072 -0.049 -0.068  0.143
# dQ3D   0.072  1.000  0.000  0.042 -0.073 -0.073 -0.118  0.064 -0.049  0.001
# dQ4A   0.102  0.000  1.000  0.046 -0.053  0.049  0.007 -0.064 -0.126 -0.114
# dQ5D   0.108  0.042  0.046  1.000  0.018  0.014  0.048 -0.112 -0.042  0.033
# dQ6S   0.032 -0.073 -0.053  0.018  1.000  0.041  0.003 -0.139  0.002  0.028
# dQ7A   0.105 -0.073  0.049  0.014  0.041  1.000  0.126 -0.120 -0.081  0.080
# dQ8S   0.072 -0.118  0.007  0.048  0.003  0.126  1.000 -0.188 -0.079  0.068
# dQ10D -0.049  0.064 -0.064 -0.112 -0.139 -0.120 -0.188  1.000 -0.078 -0.065
# dQ13D -0.068 -0.049 -0.126 -0.042  0.002 -0.081 -0.079 -0.078  1.000 -0.012
# ...

# %%
library(readr)
library(dplyr)
library(ggplot2)
library(mirt)

# Settings/locations
dec_path <- "outputs/PhaseC_C2/decisions_items.csv"
info_path <- "outputs/PhaseC_C2/test_information_curve.csv"
jack_path <- "outputs/PhaseC_C2/jackknife_delta_info.csv"
pairs_path <- "outputs/PhaseC_C2/top_Q3_pairs.csv"
mod_path <- "outputs/PhaseC_C1/mod_uni.rds"

# 1. Check that model converged and matches number of items
mod_uni <- readRDS(mod_path)
cat("\nModel converged? ", mod_uni@OptimInfo$converged, "\n")
print(length(coef(mod_uni, simplify = TRUE)$items))

# 2. Quick summary of decisions table
dec <- read_csv(dec_path, show_col_types = FALSE)
print(table(dec$ProposedAction, dec$domain, useNA="always"))
cat("\nItems proposed to DROP:\n")
print(dec %>% filter(ProposedAction == "DROP") %>%
        select(item, domain, Reason, a, mean_info_band, max_absQ3, thr_ordered))

cat("\nItems KEPT:\n")
print(dec %>% filter(ProposedAction == "KEEP") %>% select(item, domain, a, mean_info_band))

# 3. Domain coverage check
covg <- dec %>% filter(ProposedAction == "KEEP") %>% count(domain)
print(covg)
stopifnot(all(covg$n >= 2 | is.na(covg$domain)))  # Should meet MIN_KEEP_PER_DOMAIN

# 4. Visualize test information and reliability
info_df <- read_csv(info_path, show_col_types = FALSE)
p1 <- ggplot(info_df, aes(x=theta, y=test_info)) + geom_line(size=1) +
  geom_hline(yintercept=4, linetype=2, col='blue') +
  labs(title="Test Information Curve", y="Test Information", x="Theta") +
  theme_minimal()
p2 <- ggplot(info_df, aes(x=theta, y=reliability)) + geom_line(size=1) +
  geom_hline(yintercept=0.8, linetype=2, col='green4') +
  labs(title="Marginal Reliability Curve", y="Reliability", x="Theta") +
  theme_minimal()
print(p1); print(p2)

# 5. Jackknife info loss review
jack <- read_csv(jack_path, show_col_types = FALSE)
cat("\n Items with highest loss of info if removed:\n")
print(jack %>% arrange(desc(delta_info_band)) %>% head())

# 6. Q3: local dependence summary
pairs <- read_csv(pairs_path, show_col_types = FALSE)
cat("\nPairs with strongest local dependence (high Q3):\n")
print(pairs %>% arrange(desc(abs(Q3))) %>% head(10))

# 7. Any gaps or oddities?
cat("\nCheck: Any issues flagged?\n")
issues <- dec %>% filter(ProposedAction=="KEEP" & (a < 1 | thr_ordered==FALSE | mean_info_band < quantile(mean_info_band, 0.25, na.rm=TRUE)))
print(issues)

# 8. Save a HTML/markdown summary (optional; requires knitr/rmarkdown)
summary_lines <- c(
  "Phase C2 Check Summary:",
  paste("Model converged:", mod_uni@OptimInfo$converged),
  paste("Total items:", nrow(dec), "Kept:", sum(dec$ProposedAction=="KEEP"), "Dropped:", sum(dec$ProposedAction=="DROP")),
  paste("Domain coverage:", paste(covg$domain, covg$n, sep=": ", collapse="; ")),
  "See plots for information and reliability."
)
writeLines(summary_lines, "outputs/PhaseC_C2/checks_summary.txt")
# Out:
# Model converged?  TRUE
# [1] 84
#
#        Anx Dep Str <NA>
#   KEEP   7   7   7    0
#   <NA>   0   0   0    0
#
# Items proposed to DROP:
# # A tibble: 0 × 7
# # ℹ 7 variables: item <chr>, domain <chr>, Reason <chr>, a <dbl>,
# #   mean_info_band <lgl>, max_absQ3 <dbl>, thr_ordered <lgl>
#
# Items KEPT:
# # A tibble: 21 × 4
#    item  domain     a mean_info_band
#    <chr> <chr>  <dbl> <lgl>
#  1 dQ2A  Anx    0.558 NA
#  2 dQ3D  Dep    0.969 NA
#  3 dQ4A  Anx    0.886 NA
#  4 dQ5D  Dep    0.923 NA
#  5 dQ6S  Str    1.10  NA
#  6 dQ7A  Anx    1.02  NA
#  7 dQ8S  Str    1.31  NA
#  8 dQ10D Dep    1.34  NA
#  9 dQ13D Dep    1.62  NA
# 10 dQ14S Str    0.788 NA
# # ℹ 11 more rows
# # ℹ Use `print(n = ...)` to see more rows
# # A tibble: 3 × 2
#   domain     n
#   <chr>  <int>
# 1 Anx        7
# 2 Dep        7
# 3 Str        7
# Warning message:
# Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ...

# %%
library(mirt)
library(dplyr)

checks <- list()

# Check input data
inp <- tryCatch(readRDS("outputs/PhaseC_prep/phaseC_inputs.rds"), error = function(e) NULL)
checks$inp_null <- is.null(inp)
if (!is.null(inp)) {
  # Data for full DASS candidates
  dat_full <- as.data.frame(inp$resp_dass_num)
  checks$n_items <- ncol(dat_full)
  checks$n_cases <- nrow(dat_full)
  checks$all_item_names <- colnames(dat_full)
  # Check if any constant or all-missing columns
  checks$item_missing  <- sapply(dat_full, function(col) sum(is.na(col)))
  checks$item_constant <- sapply(dat_full, function(col) length(unique(col[!is.na(col)])) == 1)
  checks$n_missing_cols <- sum(checks$item_missing == nrow(dat_full))
  checks$n_constant_cols <- sum(checks$item_constant)
  checks$min_max_byitem <- sapply(dat_full, function(x) {
    paste0(min(x, na.rm=TRUE), ":", max(x, na.rm=TRUE))
  })
}

# Model object
mod_uni <- tryCatch(readRDS("outputs/PhaseC_C1/mod_uni.rds"), error=function(e) NULL)
checks$mod_null <- is.null(mod_uni)
if (!is.null(mod_uni)) {
  # Basic model diagnostics
  checks$converged <- mod_uni@OptimInfo$converged
  checks$cycles    <- mod_uni@OptimInfo$NCYCLES
  checks$logLik    <- mod_uni@Fit$logLik
  # No. items found in model
  ctab <- tryCatch(coef(mod_uni, simplify=TRUE), error=function(e) NULL)
  checks$n_items_model <- if(!is.null(ctab)) length(ctab$items) else NA
  checks$n_items_coef_names <- if(!is.null(ctab)) names(ctab$items) else NA
  # Extract.mirt availability
  extract_success <- FALSE
  items_list_test <- NULL
  try({
    items_list_test <- extract.mirt(mod_uni, "items")
    if (!is.null(items_list_test) && length(items_list_test) > 0) extract_success <- TRUE
  }, silent=TRUE)
  checks$extract_mirt_success <- extract_success
  checks$extract_n_items <- if(!is.null(items_list_test)) length(items_list_test) else NA
} else {
  checks$converged           <- NA
  checks$cycles              <- NA
  checks$logLik              <- NA
  checks$n_items_model       <- NA
  checks$n_items_coef_names  <- NA
  checks$extract_mirt_success<- NA
  checks$extract_n_items     <- NA
}

# Print all checks as plain output
for (nm in names(checks)) {
  cat(sprintf("%-24s : %s\n", nm, paste0(checks[[nm]], collapse=", ")))
}
# Out:
# inp_null                 : FALSE
# n_items                  : 21
# n_cases                  : 851
# all_item_names           : dQ2A, dQ3D, dQ4A, dQ5D, dQ6S, dQ7A, dQ8S, dQ10D, dQ13D, dQ14S, dQ16D, dQ17D, dQ18S, dQ19A, dQ20A, dQ21D, dQ1S, dQ9A, dQ11S, dQ12S, dQ15A
# item_missing             : 10, 24, 10, 15, 18, 20, 14, 12, 17, 30, 23, 14, 19, 12, 4, 2, 17, 25, 19, 7, 14
# item_constant            : FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE
# n_missing_cols           : 0
# n_constant_cols          : 0
# min_max_byitem           : 0:3, 0:3, 0:3, 0:3, 0:3, 0:3, 0:3, 0:3, 0:3, 0:3, 0:3, 0:3, 0:3, 0:3, 0:3, 0:3, 0:3, 0:3, 0:3, 0:3, 0:3
# mod_null                 : FALSE
# converged                : TRUE
# logLik                   : -21718.2236705208
# n_items_model            : 84
# extract_mirt_success     : FALSE
# extract_n_items          : NA

# %%
library(mirt)
inp <- readRDS("outputs/PhaseC_prep/phaseC_inputs.rds")
dat_full <- as.data.frame(inp$resp_dass_num)
dat_full <- dat_full %>% mutate(across(everything(), ~ as.integer(.)))
print(dim(dat_full)) # should be 851 x 21
print(length(unique(colnames(dat_full)))) # should be 21
# Out:
# [1] 851  21
# [1] 21

# %%
# Phase C: drop proposal to reach 15 items (2 removals per domain)
library(mirt)
library(dplyr)
library(readr)
library(tidyr)
library(stringr)
library(purrr)

dir.create("outputs/PhaseC_drop_packet", recursive = TRUE, showWarnings = FALSE)

# Inputs
mod_uni <- readRDS("outputs/PhaseC_C1/mod_uni.rds")
dec     <- read_csv("outputs/PhaseC_C2/decisions_items.csv", show_col_types = FALSE)
jack    <- read_csv("outputs/PhaseC_C2/jackknife_delta_info.csv", show_col_types = FALSE)
efa     <- read_csv("outputs/PhaseA_A3/DASS_item_flags_annotated.csv", show_col_types = FALSE)

# If you saved the full DASS matrix and need names
inp      <- readRDS("outputs/PhaseC_prep/phaseC_inputs.rds")
dat_full <- as.data.frame(inp$resp_dass_num)

# Sanity
stopifnot(isTRUE(mod_uni@OptimInfo$converged))
item_names <- intersect(colnames(dat_full), dec$item)

# Compute/repair mean_info_band with testinfo if NA in C2 table
Theta <- seq(-3, 3, 0.1)
band  <- Theta >= 0.5 & Theta <= 2.0

# Recompute per-item info using testinfo (robust)
recomp_info <- purrr::map_dfr(seq_along(item_names), function(k){
  nm <- item_names[k]
  idx <- match(nm, colnames(dat_full))
  inf_k <- testinfo(mod_uni, Theta, which.items = idx)
  tibble(item = nm,
         mean_info_band_recomp = mean(inf_k[band], na.rm = TRUE),
         peak_info_recomp      = max(inf_k, na.rm = TRUE))
})

# Merge all diagnostics
# Bring in EFA primary loading as a tie-breaker (if available)
efa_keep <- efa %>% select(item, primary_loading) %>% distinct()
diag <- dec %>%
  left_join(jack, by = "item") %>%
  left_join(recomp_info, by = "item") %>%
  left_join(efa_keep, by = "item") %>%
  mutate(
    mean_info_band = coalesce(as.numeric(mean_info_band), mean_info_band_recomp),
    peak_info      = coalesce(as.numeric(peak_info), peak_info_recomp),
    domain = case_when(
      str_detect(item, "D$") ~ "Dep",
      str_detect(item, "A$") ~ "Anx",
      str_detect(item, "S$") ~ "Str",
      TRUE ~ domain
    ),
    # Flags
    misfit_flag = (!is.na(p) & p < 0.01) | (!is.na(infit) & abs(infit - 1) > 0.2),
    thr_bad     = isFALSE(thr_ordered),
    q3_flag     = !is.na(max_absQ3) & max_absQ3 >= 0.25,
    low_a       = !is.na(a) & a < 1
  )

# Domain-wise scaling and composite score
score_by_domain <- function(df){
  rng <- function(x) if(all(is.na(x))) x else (x - min(x, na.rm=TRUE)) / (max(x, na.rm=TRUE) - min(x, na.rm=TRUE) + 1e-9)
  df %>%
    mutate(
      s_info = rng(mean_info_band),
      s_a    = rng(a),
      s_jack = rng(delta_info_band),
      s_efa  = rng(abs(primary_loading)),
      # Composite: weights prioritize information, then a, then jackknife, with EFA as tie-breaker; penalties subtract
      comp = 0.45*s_info + 0.30*s_a + 0.15*s_jack + 0.10*s_efa -
             0.25*as.numeric(misfit_flag) - 0.25*as.numeric(q3_flag) - 1.0*as.numeric(thr_bad)
    )
}
diag2 <- diag %>%
  group_by(domain) %>%
  group_modify(~ score_by_domain(.x)) %>%
  ungroup()

# Propose drops: two lowest composite per domain (keep >=5 per domain)
drop_per_domain <- 2L
proposal <- diag2 %>%
  group_by(domain) %>%
  arrange(comp, .by_group = TRUE) %>%
  mutate(rank_in_domain = row_number()) %>%
  ungroup() %>%
  group_by(domain) %>%
  slice_head(n = drop_per_domain) %>%
  ungroup() %>%
  mutate(Decision = "DROP_proposed", Rationale = "lowest composite (info/a/Δinfo) + penalties (misfit/Q3/threshold)")

keep_set <- setdiff(item_names, proposal$item)

# Verify reliability/info after dropping 6 items
TI_base <- testinfo(mod_uni, Theta)
REL_base <- TI_base/(TI_base+1)

# Refit reduced model (optional quick check inside the packet)
dat_red <- dat_full[, keep_set, drop = FALSE]
set.seed(20250912)
mod_red <- mirt(dat_red, 1, itemtype = "graded", method = "EM", technical = list(NCYCLES = 800))
TI_red  <- testinfo(mod_red, Theta)
REL_red <- TI_red/(TI_red+1)

# Export the packet
readr::write_csv(
  diag2 %>%
    arrange(domain, desc(comp)) %>%
    select(item, domain, a, starts_with("b."), thr_ordered, p, infit, max_absQ3,
           mean_info_band, delta_info_band, primary_loading, comp),
  "outputs/PhaseC_drop_packet/item_diagnostics_scored.csv"
)

readr::write_csv(proposal %>% select(item, domain, a, mean_info_band, max_absQ3, comp, Rationale),
                 "outputs/PhaseC_drop_packet/drop_recommendations.csv")
writeLines(keep_set, "outputs/PhaseC_drop_packet/shortform_15_items.txt")

readr::write_csv(data.frame(theta = Theta, test_info = TI_base, reliability = REL_base),
                 "outputs/PhaseC_drop_packet/test_info_base.csv")
readr::write_csv(data.frame(theta = Theta, test_info = TI_red,  reliability = REL_red),
                 "outputs/PhaseC_drop_packet/test_info_reduced_15.csv")

# Quick console preview
cat("\nProposed drops (2 per domain):\n")
print(proposal %>% arrange(domain, comp) %>% select(domain, item, comp, a, mean_info_band, max_absQ3))
cat("\nKept (15 items):\n")
print(keep_set)
# Out:
# Iteration: 19, Log-Lik: -15489.632, Max-Change: 0.00009
#
# Proposed drops (2 per domain):
# # A tibble: 6 × 6
#   domain item   comp     a mean_info_band max_absQ3
#   <chr>  <chr> <dbl> <dbl>          <dbl>     <dbl>
# 1 Anx    dQ2A     NA 0.558         0.0924     0.169
# 2 Anx    dQ4A     NA 0.886         0.241      0.148
# 3 Dep    dQ3D     NA 0.969         0.287      0.140
# 4 Dep    dQ5D     NA 0.923         0.241      0.190
# 5 Str    dQ6S     NA 1.10          0.353      0.155
# 6 Str    dQ8S     NA 1.31          0.426      0.213
#
# Kept (15 items):
#  [1] "dQ7A"  "dQ10D" "dQ13D" "dQ14S" "dQ16D" "dQ17D" "dQ18S" "dQ19A" "dQ20A"
# [10] "dQ21D" "dQ1S"  "dQ9A"  "dQ11S" "dQ12S" "dQ15A"

# %%
# Phase C3: finalize 15-item short form after review

# %%
# Phase C2.5 -> C4: finalize 15-item GRM, scoring, precision, optional ROC, exports

# ---- Configuration ----
library(mirt)
library(readr)
library(dplyr)
library(tidyr)
suppressWarnings({ library(broom) }) # optional; script falls back if unavailable

set.seed(20250912)
dir.create("outputs/PhaseC_final15", recursive = TRUE, showWarnings = FALSE)

# Inputs
path_keep15   <- "outputs/PhaseC_drop_packet/shortform_15_items.txt"
path_inp      <- "outputs/PhaseC_prep/phaseC_inputs.rds"       # contains inp$resp_dass_num and inp$id
path_mod21    <- "outputs/PhaseC_C1/mod_uni.rds"               # optional baseline 21-item unidimensional model

# Optional: copy-through of earlier artifacts if they exist (not regenerated here)
for (f in c("outputs/PhaseC_drop_packet/item_diagnostics_scored.csv",
            "outputs/PhaseC_drop_packet/drop_recommendations.csv")) {
  if (file.exists(f)) file.copy(f, file.path("outputs/PhaseC_final15", basename(f)), overwrite = TRUE)
}

# ---- Safety checks ----
stopifnot(file.exists(path_keep15))
stopifnot(file.exists(path_inp))
keep15 <- readLines(path_keep15)
inp    <- readRDS(path_inp)

# ---- Data slice ----
dat_all <- as.data.frame(inp$resp_dass_num)
if (!all(keep15 %in% names(dat_all))) {
  stop("Some keep15 items are not in inp$resp_dass_num. Check names in shortform_15_items.txt.")
}
dat15 <- dat_all[, keep15, drop = FALSE]

# ---- Fit GRM on 15 items ----
mod15 <- mirt(dat15, 1, itemtype = "graded", method = "EM", SE = TRUE,
              technical = list(NCYCLES = 2000))
saveRDS(mod15, "outputs/PhaseC_final15/mod15.rds")

# ---- Item parameters ----
pars15 <- coef(mod15, IRTpars = TRUE, simplify = TRUE)$items %>%
  as.data.frame() %>% tibble::rownames_to_column("item")
write_csv(pars15, "outputs/PhaseC_final15/item_parameters_15.csv")

# ---- Item fit (S-X2) and Q3 ----
itemfit_out <- tryCatch(
  {
    if (ncol(dat15) <= 200) { # S-X2 can be heavy; small guard
      itf <- itemfit(mod15)
      as.data.frame(itf)
    } else {
      data.frame()
    }
  },
  error = function(e) data.frame()
)
if (nrow(itemfit_out)) {
  itemfit_out$item <- rownames(itemfit_out)
  rownames(itemfit_out) <- NULL
  write_csv(itemfit_out, "outputs/PhaseC_final15/itemfit_15.csv")
}

# Q3 matrix -> top pairs
q3 <- tryCatch(residuals(mod15, type = "Q3"), error = function(e) NULL)
if (!is.null(q3)) {
  q3_df <- as.data.frame(q3)
  q3_df$lhs <- rownames(q3_df)
  q3_long <- pivot_longer(q3_df, -lhs, names_to = "rhs", values_to = "Q3") %>%
    filter(lhs < rhs) %>% arrange(desc(Q3))
  write_csv(head(q3_long, 100), "outputs/PhaseC_final15/top_Q3_pairs_15.csv")
}

# ---- Test information & reliability (reduced and baseline) ----
Theta <- seq(-3, 3, by = 0.1)
TI15  <- testinfo(mod15, Theta)
REL15 <- TI15/(TI15 + 1)
reduced_df <- data.frame(theta = Theta, test_info = TI15, reliability = REL15)
write_csv(reduced_df, "outputs/PhaseC_final15/test_info_reduced_15.csv")
# Backward-compat name if needed
write_csv(reduced_df, "outputs/PhaseC_final15/test_info_15.csv")

# Baseline info from 21-item model if available
if (file.exists(path_mod21)) {
  mod21 <- readRDS(path_mod21)
  TI21  <- testinfo(mod21, Theta)
  REL21 <- TI21/(TI21 + 1)
  base_df <- data.frame(theta = Theta, test_info = TI21, reliability = REL21)
  write_csv(base_df, "outputs/PhaseC_final15/test_info_base.csv")
}

# Quick console check
idx1 <- which.min(abs(Theta - 1))
cat("mod15 converged? ", mod15@OptimInfo$converged, "\n",
    "Reliability at theta = 1.0 (reduced): ", round(REL15[idx1], 3), "\n")

# ---- EAP scoring (with SE) + raw sum ----
fs15 <- fscores(mod15, method = "EAP", full.scores.SE = TRUE)
theta15 <- as.numeric(fs15[,"F1"])
se15    <- as.numeric(fs15[,"SE_F1"])
scores  <- data.frame(id = inp$id, theta15 = theta15, se15 = se15,
                      raw_sum15 = rowSums(dat15, na.rm = TRUE))
write_csv(scores, "outputs/PhaseC_final15/scores_15.csv")

# ---- Raw-sum to theta mapping (linear; simple field lookup) ----
scores_nona <- scores[!is.na(scores$theta15) & !is.na(scores$raw_sum15), ]
lm_map <- lm(theta15 ~ raw_sum15, data = scores_nona)
saveRDS(lm_map, "outputs/PhaseC_final15/rawsum_to_theta_map.rds")
if ("broom" %in% .packages()) {
  write_csv(broom::tidy(lm_map), "outputs/PhaseC_final15/rawsum_to_theta_coeffs.csv")
} else {
  coefs <- data.frame(term = rownames(coef(summary(lm_map))),
                      estimate = coef(summary(lm_map))[,1],
                      std.error = coef(summary(lm_map))[,2],
                      statistic = coef(summary(lm_map))[,3],
                      p.value = coef(summary(lm_map))[,4])
  write_csv(coefs, "outputs/PhaseC_final15/rawsum_to_theta_coeffs.csv")
}
max_sum <- max(scores$raw_sum15, na.rm = TRUE)
lookup <- data.frame(raw_sum15 = 0:max_sum)
lookup$theta_hat <- predict(lm_map, newdata = lookup)
write_csv(lookup, "outputs/PhaseC_final15/lookup_rawsum_to_theta.csv")

# ---- Optional ROC (only if explicitly enabled and labels are present) ----
# Provide either a CSV path OR an in-memory object name (e.g., "phase4_clusters") with columns id + cluster
run_roc <- FALSE
clusters_path <- NA_character_  # e.g., "outputs/Phase4/final_clusters.csv"
clusters_object_name <- NA_character_  # e.g., "phase4_clusters"

roc_ready <- FALSE
clusters <- NULL
if (isTRUE(run_roc)) {
  if (!is.na(clusters_path) && nzchar(clusters_path) && file.exists(clusters_path)) {
    clusters <- tryCatch(readr::read_csv(clusters_path, show_col_types = FALSE), error = function(e) NULL)
  } else if (!is.na(clusters_object_name) && nzchar(clusters_object_name) && exists(clusters_object_name)) {
    clusters <- get(clusters_object_name, inherits = TRUE)
  }
  roc_ready <- !is.null(clusters) && all(c("id") %in% names(clusters)) &&
               any(c("cluster","label") %in% names(clusters))
}

if (isTRUE(run_roc) && roc_ready) {
  # Harmonize to binary: assume cluster 2/C2/high = high distress; edit if inverted
  if ("cluster" %in% names(clusters)) {
    clusters$high_distress <- ifelse(clusters$cluster %in% c(2,"2","C2","high","High"), 1L, 0L)
  } else if ("label" %in% names(clusters)) {
    clusters$high_distress <- ifelse(clusters$label %in% c(2,"2","C2","high","High"), 1L, 0L)
  } else {
    stop("Provide 'cluster' or 'label' column in clusters.")
  }
  crit_df <- scores %>% inner_join(clusters[,c("id","high_distress")], by = "id")
  write_csv(crit_df, "outputs/PhaseC_final15/scores_with_cluster.csv")

  # ROC
  suppressPackageStartupMessages(library(pROC))
  r <- pROC::roc(response = crit_df$high_distress, predictor = crit_df$theta15,
                 quiet = TRUE, direction = ">")
  auc_ci <- pROC::ci.auc(r)
  coords_youden <- pROC::coords(r, x = "best", best.method = "youden",
                                ret = c("threshold","sensitivity","specificity","ppv","npv"))
  write_csv(data.frame(threshold = coords_youden["threshold"],
                       sensitivity = coords_youden["sensitivity"],
                       specificity = coords_youden["specificity"],
                       ppv = coords_youden["ppv"],
                       npv = coords_youden["npv"]),
            "outputs/PhaseC_final15/roc_operating_point.csv")
  png("outputs/PhaseC_final15/roc_curve.png", width = 900, height = 700, res = 150)
  plot(r, print.auc = TRUE,
       main = sprintf("ROC short form vs high distress (AUC=%.3f)", as.numeric(auc_ci[21])))
  dev.off()
  cat(sprintf("ROC AUC = %.3f (95%% CI %.3f–%.3f). Suggested theta cut = %.3f\n",
              as.numeric(auc_ci[21]), as.numeric(auc_ci[22]), as.numeric(auc_ci[23]),
              as.numeric(coords_youden["threshold"])))
} else {
  cat("ROC skipped: set run_roc <- TRUE and supply clusters_path or clusters_object_name with id + cluster.\n")
}
# Out:
# Iteration: 19, Log-Lik: -15489.632, Max-Change: 0.00009
#
# Calculating information matrix...
# Q3 summary statistics:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  -0.248  -0.110  -0.062  -0.055  -0.007   0.214
#
#         dQ7A  dQ10D  dQ13D  dQ14S  dQ16D  dQ17D  dQ18S  dQ19A  dQ20A  dQ21D
# dQ7A   1.000 -0.104 -0.035  0.111 -0.022 -0.164  0.094  0.058 -0.048 -0.202
# dQ10D -0.104  1.000 -0.126 -0.062  0.061  0.066 -0.248 -0.186 -0.128  0.080
# dQ13D -0.035 -0.126  1.000  0.017 -0.065 -0.113  0.089 -0.078 -0.165 -0.104
# dQ14S  0.111 -0.062  0.017  1.000 -0.023 -0.180  0.097 -0.007 -0.100 -0.122
# dQ16D -0.022  0.061 -0.065 -0.023  1.000  0.037 -0.119 -0.106 -0.154 -0.018
# dQ17D -0.164  0.066 -0.113 -0.180  0.037  1.000 -0.083 -0.164 -0.072  0.214
# dQ18S  0.094 -0.248  0.089  0.097 -0.119 -0.083  1.000  0.053  0.062 -0.145
# dQ19A  0.058 -0.186 -0.078 -0.007 -0.106 -0.164  0.053  1.000  0.069 -0.114
# ...

# %%
# Minimal DIF screen (optional)
if (!is.null(inp$gender)) {
  grp <- factor(inp$gender)
  mod_mg <- multipleGroup(dat15, 1, group = grp, itemtype = "graded",
                          invariance = c("free_means", "free_var"))
  # Uniform DIF: free item slopes (a) across groups
  LRT_uniform <- DIF(mod_mg, which.items = 1:ncol(dat15), scheme = "drop", items2test = 1:ncol(dat15),
                     type = "both") # both tests across a/b parameters
  # Save results
  capture.output(print(LRT_uniform), file = "outputs/PhaseC_final15/dif_gender_uniform.txt")
}

# %%
# Inputs
library(mirt); library(ggplot2); library(reshape2); library(dplyr); library(tidyr); library(readr)
dir.create("outputs/PhaseC_final15/figs", recursive = TRUE, showWarnings = FALSE)
mod15 <- readRDS("outputs/PhaseC_final15/mod15.rds")

# 1) Q3 residual heatmap and top pairs
q3 <- residuals(mod15, type = "Q3")
q3m <- melt(q3, varnames = c("lhs","rhs"), value.name = "Q3")
q3m <- q3m %>% filter(lhs != rhs)
p_q3 <- ggplot(q3m, aes(lhs, rhs, fill = Q3)) +
  geom_tile() + scale_fill_viridis_c() + coord_equal() +
  theme(axis.text.x = element_text(angle = 90, hjust = 1)) +
  labs(title = "Q3 residuals heatmap (15-item GRM)", x = "Item", y = "Item")
ggsave("outputs/PhaseC_final15/figs/q3_heatmap_15.png", p_q3, width = 11, height = 9, dpi = 200)

q3pairs <- q3m %>% filter(as.character(lhs) < as.character(rhs)) %>% arrange(desc(Q3))
write_csv(head(q3pairs, 50), "outputs/PhaseC_final15/top_Q3_pairs_15.csv")

# 2) Category probability curves (trace) – faceted
# mirt base plot to file (works best by opening device before plotting)
png("outputs/PhaseC_final15/figs/item_traces_facet_15.png", width = 1600, height = 1200, res = 180)
plot(mod15, type = "trace", facet_items = TRUE)  # per-item facets
dev.off()

# 3) Item information curves (IIC) – faceted
png("outputs/PhaseC_final15/figs/item_info_curves_15.png", width = 1600, height = 1200, res = 180)
plot(mod15, type = "infotrace", facet_items = TRUE)
dev.off()

# 4) Discrimination and thresholds summary plots
pars15 <- readr::read_csv("outputs/PhaseC_final15/item_parameters_15.csv", show_col_types = FALSE)
# Expect columns: item, a, b1..bk (IRTpars=TRUE)
# Discrimination dotplot
p_a <- ggplot(pars15, aes(x = reorder(item, a), y = a)) +
  geom_point(size = 2) + coord_flip() + geom_hline(yintercept = 1, linetype = 2) +
  labs(title = "Item discrimination (a)", x = "Item", y = "a (slope)")
ggsave("outputs/PhaseC_final15/figs/discrimination_dotplot_15.png", p_a, width = 8, height = 6, dpi = 200)

# Thresholds long and dotplot
bcols <- grep("^b\\d+", names(pars15), value = TRUE)
bt <- pars15 |> select(item, all_of(bcols)) |> pivot_longer(-item, names_to = "thresh", values_to = "b")
p_b <- ggplot(bt, aes(x = b, y = reorder(item, b))) +
  geom_point(alpha = 0.7) + facet_wrap(~ thresh, nrow = 1) +
  labs(title = "Threshold locations (b_k)", x = "Theta (b)", y = "Item")
ggsave("outputs/PhaseC_final15/figs/thresholds_dotplot_15.png", p_b, width = 14, height = 6, dpi = 200)
# Out:
# Attaching package: ‘reshape2’
#
# The following object is masked from ‘package:tidyr’:
#
#     smiths
#
# Q3 summary statistics:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  -0.248  -0.110  -0.062  -0.055  -0.007   0.214
#
#         dQ7A  dQ10D  dQ13D  dQ14S  dQ16D  dQ17D  dQ18S  dQ19A  dQ20A  dQ21D
# dQ7A   1.000 -0.104 -0.035  0.111 -0.022 -0.164  0.094  0.058 -0.048 -0.202
# dQ10D -0.104  1.000 -0.126 -0.062  0.061  0.066 -0.248 -0.186 -0.128  0.080
# dQ13D -0.035 -0.126  1.000  0.017 -0.065 -0.113  0.089 -0.078 -0.165 -0.104
# dQ14S  0.111 -0.062  0.017  1.000 -0.023 -0.180  0.097 -0.007 -0.100 -0.122
# dQ16D -0.022  0.061 -0.065 -0.023  1.000  0.037 -0.119 -0.106 -0.154 -0.018
# dQ17D -0.164  0.066 -0.113 -0.180  0.037  1.000 -0.083 -0.164 -0.072  0.214
# dQ18S  0.094 -0.248  0.089  0.097 -0.119 -0.083  1.000  0.053  0.062 -0.145
# dQ19A  0.058 -0.186 -0.078 -0.007 -0.106 -0.164  0.053  1.000  0.069 -0.114
# ...

# %%
library(readr); library(dplyr); library(ggplot2)

reduced <- readr::read_csv("outputs/PhaseC_final15/test_info_reduced_15.csv", show_col_types = FALSE)
basepth <- "outputs/PhaseC_final15/test_info_base.csv"
base <- if (file.exists(basepth)) readr::read_csv(basepth, show_col_types = FALSE) else NULL

# TIF overlay
if (!is.null(base)) {
  tif_df <- bind_rows(reduced |> mutate(model = "Reduced-15"),
                      base    |> mutate(model = "Baseline-21"))
  band_lo <- 0.5; band_hi <- 2.0
  p_tif <- ggplot(tif_df, aes(theta, test_info, color = model)) +
    geom_line(size = 1.1) +
    annotate("rect", xmin = band_lo, xmax = band_hi, ymin = -Inf, ymax = Inf,
             alpha = 0.08, fill = "grey60") +
    labs(title = "Test information: Reduced-15 vs Baseline-21",
         x = expression(theta), y = "Test information") +
    theme(legend.position = "bottom")
  ggsave("outputs/PhaseC_final15/figs/tif_reduced_vs_base.png", p_tif, width = 9, height = 6, dpi = 200)

  # Reliability overlay
  p_rel <- ggplot(tif_df, aes(theta, reliability, color = model)) +
    geom_line(size = 1.1) +
    annotate("rect", xmin = band_lo, xmax = band_hi, ymin = -Inf, ymax = Inf,
             alpha = 0.08, fill = "grey60") +
    geom_hline(yintercept = 0.80, linetype = 2) +
    labs(title = "Reliability across theta", x = expression(theta), y = "Reliability") +
    theme(legend.position = "bottom")
  ggsave("outputs/PhaseC_final15/figs/reliability_reduced_vs_base.png", p_rel, width = 9, height = 6, dpi = 200)
}

# %%
library(readr); library(ggplot2); library(dplyr)

scores <- readr::read_csv("outputs/PhaseC_final15/scores_15.csv", show_col_types = FALSE)

# 1) Theta distribution
p_theta <- ggplot(scores |> filter(!is.na(theta15)), aes(theta15)) +
  geom_histogram(bins = 40, color = "white", fill = "#2c7fb8", alpha = 0.9) +
  geom_vline(xintercept = 0, linetype = 3) +
  labs(title = "Short-form theta distribution (15 items)", x = expression(theta[8]), y = "Count")
ggsave("outputs/PhaseC_final15/figs/theta_distribution_15.png", p_theta, width = 9, height = 6, dpi = 200)

# 2) Raw-sum to theta mapping with fit line
map <- readr::read_csv("outputs/PhaseC_final15/rawsum_to_theta_coeffs.csv", show_col_types = FALSE)
p_map <- ggplot(scores |> filter(!is.na(theta15), !is.na(raw_sum15)),
                aes(raw_sum15, theta15)) +
  geom_point(alpha = 0.25) +
  geom_smooth(method = "lm", se = TRUE, color = "#1b9e77") +
  labs(title = "Raw-sum to theta mapping", x = "Raw sum (15 items)", y = expression(theta[8]))
ggsave("outputs/PhaseC_final15/figs/rawsum_vs_theta_15.png", p_map, width = 9, height = 6, dpi = 200)
# Out:
# `geom_smooth()` using formula = 'y ~ x'

# %%
library(readr); library(dplyr)

# A) Link theta15 to Phase-3 latent distress (if available)
scores <- readr::read_csv("outputs/PhaseC_final15/scores_15.csv", show_col_types = FALSE)
sem_path <- "outputs/Phase3/latent_general_distress.csv"  # id + gdist
if (file.exists(sem_path)) {
  gdist <- readr::read_csv(sem_path, show_col_types = FALSE)
  link_df <- scores |> inner_join(gdist, by = "id") |> filter(!is.na(theta15), !is.na(gdist))
  mdl_link <- lm(gdist ~ theta15, data = link_df)
  saveRDS(mdl_link, "outputs/PhaseC_final15/link_theta_to_sem.rds")
  readr::write_csv(broom::tidy(mdl_link), "outputs/PhaseC_final15/link_lm_summary.csv")

  # Calibration plot
  dir.create("outputs/PhaseC_final15/figs", showWarnings = FALSE, recursive = TRUE)
  library(ggplot2)
  p_cal <- ggplot(link_df, aes(theta15, gdist)) +
    geom_point(alpha = 0.3) +
    geom_smooth(method = "lm", se = TRUE, color = "#d95f02") +
    labs(title = "Calibration: short-form theta to SEM latent", x = expression(theta[8]), y = "SEM latent (Phase 3)")
  ggsave("outputs/PhaseC_final15/figs/theta_to_sem_calibration.png", p_cal, width = 9, height = 6, dpi = 200)
}

# B) ROC vs Phase-4 high-distress cluster (optional; guarded)
run_roc <- FALSE
clusters_path <- "outputs/Phase4/final_clusters.csv"  # must contain id + cluster or label
if (isTRUE(run_roc) && file.exists(clusters_path)) {
  clusters <- readr::read_csv(clusters_path, show_col_types = FALSE)
  if ("cluster" %in% names(clusters)) {
    clusters$high_distress <- ifelse(clusters$cluster %in% c(2,"2","C2","high","High"), 1L, 0L)
  } else if ("label" %in% names(clusters)) {
    clusters$high_distress <- ifelse(clusters$label %in% c(2,"2","C2","high","High"), 1L, 0L)
  }
  roc_in <- scores |> inner_join(clusters |> select(id, high_distress), by = "id") |>
           filter(!is.na(high_distress), !is.na(theta15))

  if (nrow(roc_in) > 0) {
    suppressPackageStartupMessages(library(pROC))
    r <- pROC::roc(response = roc_in$high_distress, predictor = roc_in$theta15, quiet = TRUE, direction = ">")
    auc_ci <- pROC::ci.auc(r)
    coords_youden <- pROC::coords(r, x = "best", best.method = "youden",
                                  ret = c("threshold","sensitivity","specificity","ppv","npv"))
    readr::write_csv(data.frame(threshold = coords_youden["threshold"],
                                sensitivity = coords_youden["sensitivity"],
                                specificity = coords_youden["specificity"],
                                ppv = coords_youden["ppv"],
                                npv = coords_youden["npv"]),
                     "outputs/PhaseC_final15/roc_operating_point.csv")
    png("outputs/PhaseC_final15/figs/roc_curve.png", width = 900, height = 700, res = 150)
    plot(r, print.auc = TRUE,
         main = sprintf("ROC short form vs high distress (AUC=%.3f)", as.numeric(auc_ci[13])))
    dev.off()
  }
}

# %%
# Phase C4: finalize scoring, calibration to SEM, and optional ROC

library(readr)
library(dplyr)
library(ggplot2)

dir.create("outputs/PhaseC_final15/figs", recursive = TRUE, showWarnings = FALSE)

# 0) Inputs
scores_path <- "outputs/PhaseC_final15/scores_15.csv"   # id, theta15, se15, raw_sum15
sem_path    <- "outputs/Phase3/latent_general_distress.csv"  # optional: id, gdist
clusters_path <- "outputs/Phase4/final_clusters.csv"    # optional: id, cluster or label
run_roc <- FALSE                                        # flip to TRUE when labels exist

stopifnot(file.exists(scores_path))
scores <- read_csv(scores_path, show_col_types = FALSE) |> 
          filter(!is.na(theta15))

# 1) Field scoring assets (already mostly available, regenerate to be safe)
# 1a) Raw-sum -> theta mapping (linear for simplicity; can extend to splines if needed)
lm_map <- lm(theta15 ~ raw_sum15, data = scores)
saveRDS(lm_map, "outputs/PhaseC_final15/rawsum_to_theta_map.rds")

# Coefficients
coef_df <- data.frame(term = names(coef(lm_map)),
                      estimate = as.numeric(coef(lm_map)))
write_csv(coef_df, "outputs/PhaseC_final15/rawsum_to_theta_coeffs.csv")

# Lookup table for deployment (full attainable range)
max_sum <- max(scores$raw_sum15, na.rm = TRUE)
lookup <- data.frame(raw_sum15 = 0:max_sum)
lookup$theta_hat <- predict(lm_map, newdata = lookup)
write_csv(lookup, "outputs/PhaseC_final15/lookup_rawsum_to_theta.csv")

# Diagnostic plot: raw-sum vs theta with fit
p_map <- ggplot(scores, aes(raw_sum15, theta15)) +
  geom_point(alpha = 0.25) +
  geom_smooth(method = "lm", se = TRUE, color = "#1b9e77") +
  labs(title = "Raw-sum to theta mapping", x = "Raw sum (15 items)", y = expression(theta[8]))
ggsave("outputs/PhaseC_final15/figs/rawsum_vs_theta_15.png", p_map, width = 9, height = 6, dpi = 200)

# 1b) Lightweight scorer for field pipelines (saves to R file)
scorer_code <- '
score_shortform <- function(df_row, lookup_tbl) {
  # df_row: named vector/list with short-form item responses coded as in calibration
  # lookup_tbl: data.frame with raw_sum15 and theta_hat
  # Returns: list(theta_hat, raw_sum15)
  rs <- sum(unlist(df_row), na.rm = TRUE)
  # clamp
  rs_clamped <- max(min(rs, max(lookup_tbl$raw_sum15)), min(lookup_tbl$raw_sum15))
  th <- lookup_tbl$theta_hat[lookup_tbl$raw_sum15 == rs_clamped][1]
  list(theta_hat = as.numeric(th), raw_sum15 = rs)
}
'
writeLines(scorer_code, "outputs/PhaseC_final15/score_shortform.R")

# 2) Calibration: link theta15 to Phase-3 latent distress (if available)
if (file.exists(sem_path)) {
  gdist <- read_csv(sem_path, show_col_types = FALSE)  # expects id, gdist
  link_df <- scores |> inner_join(gdist, by = "id") |> filter(!is.na(gdist))
  mdl_link <- lm(gdist ~ theta15, data = link_df)
  saveRDS(mdl_link, "outputs/PhaseC_final15/link_theta_to_sem.rds")

  link_summ <- data.frame(
    intercept = unname(coef(mdl_link)[1]),
    slope = unname(coef(mdl_link)[2]),
    r_squared = summary(mdl_link)$r.squared
  )
  write_csv(link_summ, "outputs/PhaseC_final15/link_lm_summary.csv")

  # Calibration plot
  p_cal <- ggplot(link_df, aes(theta15, gdist)) +
    geom_point(alpha = 0.3) +
    geom_smooth(method = "lm", se = TRUE, color = "#d95f02") +
    labs(title = "Calibration: short-form theta to SEM latent",
         x = expression(theta[8]), y = "SEM latent (Phase 3)")
  ggsave("outputs/PhaseC_final15/figs/theta_to_sem_calibration.png", p_cal,
         width = 9, height = 6, dpi = 200)
}

# 3) ROC and operating point (guarded; only runs with labels and flag)
if (isTRUE(run_roc) && file.exists(clusters_path)) {
  clusters <- read_csv(clusters_path, show_col_types = FALSE)
  # harmonize high_distress = 1
  if ("cluster" %in% names(clusters)) {
    clusters$high_distress <- ifelse(clusters$cluster %in% c(2, "2", "C2", "high", "High"), 1L, 0L)
  } else if ("label" %in% names(clusters)) {
    clusters$high_distress <- ifelse(clusters$label %in% c(2, "2", "C2", "high", "High"), 1L, 0L)
  } else {
    stop("clusters must have 'cluster' or 'label' column.")
  }

  roc_in <- scores |> inner_join(clusters |> select(id, high_distress), by = "id") |>
    filter(!is.na(high_distress))

  if (nrow(roc_in) > 0) {
    suppressPackageStartupMessages(library(pROC))
    r <- pROC::roc(response = roc_in$high_distress, predictor = roc_in$theta15,
                   quiet = TRUE, direction = ">")
    auc_ci <- pROC::ci.auc(r)
    # Youden operating point
    coords_y <- pROC::coords(r, x = "best", best.method = "youden",
                             ret = c("threshold","sensitivity","specificity","ppv","npv"))
    write_csv(data.frame(
      threshold = as.numeric(coords_y["threshold"]),
      sensitivity = as.numeric(coords_y["sensitivity"]),
      specificity = as.numeric(coords_y["specificity"]),
      ppv = as.numeric(coords_y["ppv"]),
      npv = as.numeric(coords_y["npv"]),
      auc = as.numeric(auc_ci[2]),
      auc_ci_low = as.numeric(auc_ci[1]),
      auc_ci_high = as.numeric(auc_ci[3])
    ), "outputs/PhaseC_final15/roc_operating_point.csv")

    png("outputs/PhaseC_final15/figs/roc_curve.png", width = 900, height = 700, res = 150)
    plot(r, print.auc = TRUE,
         main = sprintf("ROC short form vs high distress (AUC=%.3f)", as.numeric(auc_ci[2])))
    dev.off()
  }
} else {
  message("ROC skipped. Set run_roc <- TRUE and provide outputs/Phase4/final_clusters.csv with id + cluster/label.")
}
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# ROC skipped. Set run_roc <- TRUE and provide outputs/Phase4/final_clusters.csv with id + cluster/label.

# %%
# C2: Fit single-group GRM, light pruning, information curves
library(mirt)
library(dplyr)
library(readr)
library(ggplot2)
library(purrr)

dir.create("outputs/PhaseC_models", recursive = TRUE, showWarnings = FALSE)

# 1) Load prepared inputs
inp <- readRDS("outputs/PhaseC_prep/phaseC_inputs.rds")
X    <- inp$resp_dass_num           # numeric DASS items (expanded)
items_all <- names(X)

# 2) Fit unidimensional GRM
set.seed(20250912)
mod1 <- mirt::mirt(X, 1, itemtype = "graded", SE = TRUE, technical = list(NCYCLES = 1000))

# 3) Item diagnostics: thresholds ordered, discrimination, residual LD
par_tab <- coef(mod1, IRTpars = TRUE, simplify = TRUE)$items %>% as.data.frame()
par_tab$item <- rownames(coef(mod1, simplify = TRUE)$items)
# Discrimination a, thresholds b1..bn
a_vals <- par_tab$a
thr_cols <- grep("^b\\d+", names(par_tab), value = TRUE)

# Check threshold monotonicity
thr_ok <- apply(par_tab[, thr_cols, drop = FALSE], 1, function(v) all(diff(as.numeric(v)) > 0, na.rm = TRUE))
diag_tbl <- data.frame(item = par_tab$item, a = a_vals, thr_ok = thr_ok, stringsAsFactors = FALSE)

# Local dependence (residuals)
ld <- residuals(mod1, type = "LD")
ld_tbl <- as.data.frame(ld)
ld_pairs <- which(abs(ld) > 10, arr.ind = TRUE)  # Q3 > ~.20 is sometimes used; here LD chi-sq>10 as a coarse flag
ld_list <- unique(apply(ld_pairs, 1, function(idx) sort(colnames(ld)[idx])))
ld_df <- if (length(ld_list)) data.frame(pair = sapply(ld_list, paste, collapse = " — ")) else data.frame(pair = character(0))

# 4) Minimal pruning rule: drop only if (a < .75 or !thr_ok) and pairwise LD suggests redundancy.
drop_flag <- diag_tbl %>%
  mutate(flag_drop = (is.na(a) | a < 0.75 | !thr_ok))

keep_items <- diag_tbl$item[!drop_flag$flag_drop]
# If many LD flags appear, consult efa/network (manual pass). For automation keep_items as above.

# 5) Refit on kept items (if any were dropped)
if (length(keep_items) < ncol(X)) {
  X2 <- X[, keep_items, drop = FALSE]
  mod_final <- mirt::mirt(X2, 1, itemtype = "graded", SE = TRUE, technical = list(NCYCLES = 1000))
} else {
  X2 <- X
  mod_final <- mod1
}

# 6) Test information curve over theta grid
theta_grid <- seq(-3, 3, by = 0.05)
TI <- testinfo(mod_final, Theta = theta_grid)
rel <- 1 - 1/TI  # marginal reliability approximation
ti_df <- data.frame(theta = theta_grid, test_info = TI, reliability = pmax(0, pmin(rel, 0.999)))
readr::write_csv(ti_df, "outputs/PhaseC_models/test_information_curve.csv")

# Plot and save
p_ti <- ggplot(ti_df, aes(theta, test_info)) +
  geom_line(color = "#2563eb") +
  geom_vline(xintercept = c(0, 1.5, 2), linetype = 3, color = "grey60") +
  labs(title = "Test information (final GRM)", y = "Information", x = expression(theta)) +
  theme_minimal(base_size = 11)
ggsave("outputs/PhaseC_models/fig_test_information.png", p_ti, width = 6.6, height = 3.8, dpi = 200)

# Export model objects and diagnostics
saveRDS(list(mod_initial = mod1, mod_final = mod_final, keep_items = keep_items,
             item_diag = diag_tbl, ld_pairs = ld_df),
        "outputs/PhaseC_models/grm_models_and_diagnostics.rds")

readr::write_csv(diag_tbl, "outputs/PhaseC_models/item_diagnostics.csv")
readr::write_csv(data.frame(keep_items = keep_items), "outputs/PhaseC_models/keep_items.csv")
readr::write_csv(ld_df, "outputs/PhaseC_models/ld_pairs.csv")
# Out:
# Iteration: 33, Log-Lik: -21718.224, Max-Change: 0.00008
#
# Calculating information matrix...
# LD matrix (lower triangle) and standardized residual correlations (upper triangle)
#
# Upper triangle summary:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  -0.167  -0.110  -0.071  -0.008   0.106   0.189
#
#         dQ2A   dQ3D   dQ4A   dQ5D   dQ6S   dQ7A   dQ8S  dQ10D  dQ13D  dQ14S  dQ16D  dQ17D  dQ18S  dQ19A  dQ20A
# dQ2A          0.085  0.124  0.124  0.086  0.145  0.098 -0.097 -0.082  0.119 -0.128 -0.142  0.092  0.127 -0.079
# dQ3D  17.743         0.044  0.090 -0.106 -0.100 -0.101  0.090 -0.130 -0.129  0.110  0.087 -0.101 -0.082 -0.082
# dQ4A  38.588  4.748         0.103 -0.066  0.095  0.082 -0.044 -0.100 -0.121 -0.083 -0.068 -0.092  0.129  0.061
# dQ5D  38.327 19.839 26.084         0.082  0.076  0.092 -0.135  0.111  0.149  0.112 -0.095  0.086  0.119 -0.085
# dQ6S  18.240 27.244 10.716 16.666         0.115  0.093 -0.120  0.128  0.122 -0.080 -0.102  0.119 -0.098 -0.112
# ...

# %%
# Phase C4: final GRM scoring, calibration to latent scale, and ROC cut-scores
library(mirt)       # GRM, scoring, information
library(readr)
library(dplyr)
library(ggplot2)
library(pROC)       # ROC/AUC and threshold utilities

set.seed(20250912)

# 0) Load prepared inputs
inp <- readRDS("outputs/PhaseC_prep/phaseC_inputs.rds")
X_all  <- inp$resp_dass_num       # numeric DASS response matrix
id     <- inp$id

# 1) Choose final item set: prefer user-specified, else diagnostics-based, else all candidates
# --- Replace or insert after loading phaseC_inputs.rds etc. ---
# Specify your short form
final_items <- c(
  "dQ7A","dQ10D","dQ13D","dQ14S","dQ16D",
  "dQ17D","dQ18S","dQ19A","dQ20A","dQ21D",
  "dQ1S","dQ9A","dQ11S","dQ12S","dQ15A"
)

X <- X_all[, final_items, drop = FALSE]

# --- Then proceed from GRM fit, scoring, calibration, and ROC as before ---
# ... (Use the remaining blocks from the C4 script above, unchanged)


if (is.null(final_items) && file.exists("outputs/PhaseC_prep/item_diagnostics_scored.csv")) {
  diag <- read_csv("outputs/PhaseC_prep/item_diagnostics_scored.csv", show_col_types = FALSE)
  # Heuristic: keep top 12 by discrimination or test info; adjust n_keep as desired
  n_keep <- 12L
  if ("a" %in% names(diag)) {
    final_items <- diag %>% arrange(desc(a)) %>% slice_head(n = n_keep) %>% pull(item)
  } else if ("info_peak" %in% names(diag)) {
    final_items <- diag %>% arrange(desc(info_peak)) %>% slice_head(n = n_keep) %>% pull(item)
  }
}

if (is.null(final_items)) {
  final_items <- intersect(colnames(X_all), inp$dass_cand)
}

stopifnot(length(final_items) >= 6)
X <- X_all[, final_items, drop = FALSE]

# 2) Fit unidimensional GRM
#    (Skip bifactor unless previous diagnostics showed material misfit; single-group GRM is standard here)
mod <- mirt(X, 1, itemtype = "graded", SE = TRUE, method = "MHRM")  # robust for polytomous items
saveRDS(mod, "outputs/PhaseC_prep/final_grm_model.rds")

# 3) EAP scoring with SEs
scr <- fscores(mod, method = "EAP", full.scores.SE = TRUE)
scores <- data.frame(id = id, theta = scr[,"F1"], se = scr[,"SE_F1"])
write_csv(scores, "outputs/PhaseC_prep/final_grm_scores.csv")

# 4) Test information curve (for documentation)
theta_grid <- seq(-3, 3, by = 0.1)
TI <- testinfo(mod, Theta = theta_grid)
ti_df <- data.frame(theta = theta_grid, test_info = TI,
                    rel = TI / (TI + 1))  # marginal reliability approximation
write_csv(ti_df, "outputs/PhaseC_prep/final_test_information.csv")

p_ti <- ggplot(ti_df, aes(theta, test_info)) +
  geom_line(color = "#0ea5e9") +
  labs(title = "Short-form test information", x = expression(theta), y = "Information") +
  theme_minimal(base_size = 11)
ggsave("outputs/PhaseC_prep/fig_test_information.png", p_ti, width = 6.4, height = 3.8, dpi = 200,bg="white")

# 5) Calibration to validated latent scale (Phase 3/4 backbone)
#    Option A: use Phase 4 latent inputs to form a distress composite (mean z of Dep, Anx, Str)
cal <- NULL
if (file.exists("outputs/Phase4/phase4_latent_inputs.csv")) {
  lat <- read_csv("outputs/Phase4/phase4_latent_inputs.csv", show_col_types = FALSE)
  # z-score latents then average for a composite criterion
  zcols <- c("Dep","Anx","Str")
  lat <- lat %>% mutate(across(all_of(zcols), scale, .names = "z_{col}"),
                        crit = rowMeans(pick(starts_with("z_")), na.rm = TRUE))
  cal <- lat %>% select(id, crit)
}

# Join scores with calibration criterion if available
if (!is.null(cal)) {
  dat_cal <- scores %>% inner_join(cal, by = "id")
  fit_link <- lm(crit ~ theta, data = dat_cal)
  link_coefs <- coef(fit_link)
  write_csv(data.frame(term = names(link_coefs), estimate = as.numeric(link_coefs)),
            "outputs/PhaseC_prep/calibration_linear_coeffs.csv")

  # Add calibrated scale for reporting consistency
  scores <- scores %>% mutate(theta_cal = link_coefs[4] + link_coefs[5] * theta)
  write_csv(scores, "outputs/PhaseC_prep/final_grm_scores_calibrated.csv")
}

# 6) ROC/AUC and operating cut-scores
#    Criterion priority:
#      (1) High-distress cluster label if available, aligned to which cluster has higher Dep/Anx/Str.
#      (2) Else classify "elevated" by latent composite crit > +1 SD.
lab_path <- "outputs/Phase4/labels_k2_final.csv"
roc_out <- NULL

if (file.exists(lab_path) && file.exists("outputs/Phase4/phase4_latent_inputs.csv")) {
  # Determine which cluster is higher distress using latent composite
  lat <- read_csv("outputs/Phase4/phase4_latent_inputs.csv", show_col_types = FALSE)
  labs <- read_csv(lab_path, show_col_types = FALSE)
  lat <- lat %>% mutate(crit = rowMeans(scale(across(all_of(c("Dep","Anx","Str")))), na.rm = TRUE)) %>%
    select(id, crit)
  join_lab <- labs %>% inner_join(lat, by = "id")
  cl_means <- join_lab %>% group_by(cluster) %>% summarize(m = mean(crit, na.rm = TRUE), .groups = "drop")
  high_cluster <- cl_means$cluster[which.max(cl_means$m)]

  dat_roc <- scores %>%
    inner_join(labs, by = "id") %>%
    mutate(y = as.integer(cluster == high_cluster))  # 1 = high distress

  roc_fit <- roc(response = dat_roc$y, predictor = dat_roc$theta, quiet = TRUE)
  # Youden optimal and a sensitivity-prioritized option (e.g., sens >= .80)
  youden <- coords(roc_fit, "best", best.method = "youden", transpose = FALSE)
  sens80 <- suppressWarnings(coords(roc_fit, x = 0.80, input = "sensitivity", transpose = FALSE))
  roc_out <- list(auc = as.numeric(auc(roc_fit)), youden = youden, sens80 = sens80)
  saveRDS(roc_fit, "outputs/PhaseC_prep/roc_fit_theta_vs_cluster.rds")
  write_csv(as.data.frame(roc_out$youden), "outputs/PhaseC_prep/roc_cut_youden.csv")
  write_csv(as.data.frame(roc_out$sens80), "outputs/PhaseC_prep/roc_cut_sens80.csv")

  png("outputs/PhaseC_prep/fig_roc_curve.png", width = 720, height = 520, res = 120,bg="white")
  plot.roc(roc_fit, print.auc = TRUE, col = "#059669", main = "ROC: theta vs high-distress cluster")
  abline(0,1,lty=2,col="grey60")
  dev.off()
} else if (!is.null(cal)) {
  # Fall back: elevated if crit > +1 SD
  dat_roc <- scores %>% inner_join(cal, by = "id") %>%
    mutate(y = as.integer(scale(crit) > 1))
  roc_fit <- roc(response = dat_roc$y, predictor = dat_roc$theta, quiet = TRUE)
  youden <- coords(roc_fit, "best", best.method = "youden", transpose = FALSE)
  sens80 <- suppressWarnings(coords(roc_fit, x = 0.80, input = "sensitivity", transpose = FALSE))
  roc_out <- list(auc = as.numeric(auc(roc_fit)), youden = youden, sens80 = sens80)
  saveRDS(roc_fit, "outputs/PhaseC_prep/roc_fit_theta_vs_latent.rds")
  write_csv(as.data.frame(roc_out$youden), "outputs/PhaseC_prep/roc_cut_youden.csv")
  write_csv(as.data.frame(roc_out$sens80), "outputs/PhaseC_prep/roc_cut_sens80.csv")

  png("outputs/PhaseC_prep/fig_roc_curve.png", width = 720, height = 520, res = 120)
  plot.roc(roc_fit, print.auc = TRUE, col = "#059669", main = "ROC: theta vs latent criterion (+1 SD)")
  abline(0,1,lty=2,col="grey60")
  dev.off()
}

# 7) One-page summary text
summ <- c(
  paste("Final items (n =", length(final_items), "):", paste(final_items, collapse = ", ")),
  paste("Model = GRM; method = MHRM; scores = EAP; outputs saved in outputs/PhaseC_prep"),
  if (!is.null(roc_out)) paste0("ROC AUC = ", round(roc_out$auc, 3)) else "ROC not computed (no criterion found)",
  "Cut-scores saved: roc_cut_youden.csv (balanced) and roc_cut_sens80.csv (sens-prioritized)"
)
writeLines(summ, "outputs/PhaseC_prep/summary_phaseC4.txt")
# Out:
# Stage 3 = 39, CDLL = -15854.3, AR(1.07) = [0.41], gam = 0.0116, Max-Change = 0.0006
#
# Calculating information matrix...
#
# Calculating log-likelihood...

# %%
# Phase C4 visuals and final deliverables (fixed)

library(mirt)
library(readr)
library(dplyr)
library(ggplot2)
library(pROC)
library(stringr)
library(tidyr)

dir.create("outputs/PhaseC_final", recursive = TRUE, showWarnings = FALSE)

# 0) Inputs
mod    <- readRDS("outputs/PhaseC_prep/final_grm_model.rds")
scores <- readr::read_csv("outputs/PhaseC_prep/final_grm_scores.csv", show_col_types = FALSE)
scores_cal_path <- "outputs/PhaseC_prep/final_grm_scores_calibrated.csv"
if (file.exists(scores_cal_path)) scores <- readr::read_csv(scores_cal_path, show_col_types = FALSE)

# ROC objects (optional)
roc_y_path    <- "outputs/PhaseC_prep/roc_cut_youden.csv"
roc_s_path    <- "outputs/PhaseC_prep/roc_cut_sens80.csv"
roc_fit_path1 <- "outputs/PhaseC_prep/roc_fit_theta_vs_cluster.rds"
roc_fit_path2 <- "outputs/PhaseC_prep/roc_fit_theta_vs_latent.rds"
roc_fit <- if (file.exists(roc_fit_path1)) readRDS(roc_fit_path1) else if (file.exists(roc_fit_path2)) readRDS(roc_fit_path2) else NULL
youden <- if (file.exists(roc_y_path)) readr::read_csv(roc_y_path, show_col_types = FALSE) else NULL
sens80 <- if (file.exists(roc_s_path)) readr::read_csv(roc_s_path, show_col_types = FALSE) else NULL

# 1) Item parameter table and discrimination barplot
cf <- coef(mod, IRTpars = TRUE, simplify = TRUE)
it <- as.data.frame(cf$items)
it$item <- rownames(cf$items)
keep_cols <- c("item", "a", grep("^b\\d+", names(it), value = TRUE))
it_tbl <- it[, keep_cols, drop = FALSE]
readr::write_csv(it_tbl, "outputs/PhaseC_final/table_item_parameters.csv")

it_tbl <- it_tbl %>%
  mutate(domain = case_when(
    str_detect(item, "D$") ~ "Dep",
    str_detect(item, "A$") ~ "Anx",
    str_detect(item, "S$") ~ "Str",
    TRUE ~ NA_character_
  ))

p_disc <- it_tbl %>%
  arrange(desc(a)) %>%
  mutate(item = factor(item, levels = rev(item))) %>%
  ggplot(aes(x = item, y = a, fill = domain)) +
  geom_col() +
  coord_flip() +
  labs(title = "Short-form item discrimination (a)", x = "", y = "Discrimination (a)") +
  theme_minimal(base_size = 11)
ggsave("outputs/PhaseC_final/fig_item_discrimination.png", p_disc, width = 6.4, height = 5.6, dpi = 200,bg="white")

# 2) Item category (trace) curves (first 6 items)
png("outputs/PhaseC_final/fig_trace_curves_items_1to15.png", width = 1200, height = 800, res = 150)
plot(mod, type = "trace", which.items = 1:15, facet_items = TRUE)
dev.off()

# 3) Test information with shaded screening band (fixed: use annotate)
theta_grid <- seq(-3, 3, by = 0.05)
TI <- testinfo(mod, Theta = theta_grid)
ti_df <- data.frame(theta = theta_grid, test_info = TI, rel = TI/(TI+1))
screen_lo <- 0.0; screen_hi <- 2.0

p_ti <- ggplot(ti_df, aes(theta, test_info)) +
  annotate("rect", xmin = screen_lo, xmax = screen_hi, ymin = -Inf, ymax = Inf,
           fill = "#ecfeff", alpha = 0.5) +
  geom_line(color = "#0ea5e9", linewidth = 1) +
  labs(title = "Short-form test information (screening band shaded)",
       x = expression(theta), y = "Information") +
  theme_minimal(base_size = 11)
ggsave("outputs/PhaseC_final/fig_test_information_band.png", p_ti, width = 7.0, height = 4.2, dpi = 200,bg="white")

# 4) Theta distribution and raw-sum mapping (if present)
if (all(c("theta","raw_sum") %in% names(scores))) {
  p_theta <- ggplot(scores |> filter(!is.na(theta)), aes(theta)) +
    geom_histogram(bins = 40, color = "white", fill = "#2c7fb8", alpha = 0.9) +
    labs(title = "Theta distribution", x = expression(theta), y = "Count")
  ggsave("outputs/PhaseC_final/fig_theta_distribution.png", p_theta, width = 7, height = 4.2, dpi = 200)

  p_map <- ggplot(scores |> filter(!is.na(theta), !is.na(raw_sum)),
                  aes(raw_sum, theta)) +
    geom_point(alpha = 0.25) +
    geom_smooth(method = "lm", se = TRUE, color = "#1b9e77") +
    labs(title = "Raw-sum to theta mapping", x = "Raw sum (15 items)", y = expression(theta))
  ggsave("outputs/PhaseC_final/fig_rawsum_vs_theta.png", p_map, width = 7, height = 4.2, dpi = 200)
}

# 5) Calibration plot if calibrated scores exist
if ("theta_cal" %in% names(scores) && "theta" %in% names(scores)) {
  p_cal <- ggplot(scores, aes(theta, theta_cal)) +
    geom_point(alpha = 0.25, size = 1.4, color = "#0f766e") +
    geom_smooth(method = "lm", se = TRUE, color = "#0ea5e9") +
    labs(title = "Calibration: short-form theta to latent scale",
         x = "Short-form theta (EAP)", y = "Calibrated latent")
  ggsave("outputs/PhaseC_final/fig_calibration_theta.png", p_cal, width = 6.4, height = 4.5, dpi = 200)
}

# 6) ROC with annotated cut-scores (fixed coords usage)
if (!is.null(roc_fit)) {
  png("outputs/PhaseC_final/fig_ROC_annotated.png", width = 900, height = 650, res = 140)
  plot.roc(roc_fit, print.auc = TRUE, col = "#059669", main = "ROC: short-form theta vs criterion")
  abline(0, 1, lty = 2, col = "grey60")

  # Youden point
  pts_y <- pROC::coords(roc_fit, x = "best", best.method = "youden",
                        ret = c("threshold","sensitivity","specificity"),
                        transpose = FALSE)
  points(1 - pts_y["specificity"], pts_y["sensitivity"], pch = 19, col = "#1d4ed8")
  text(1 - pts_y["specificity"], pts_y["sensitivity"], labels = "Youden", pos = 4, col = "#1d4ed8", cex = 0.9)

  # Sens >= 0.80 (derive directly from ROC)
  pts_s80 <- pROC::coords(roc_fit, x = 0.80, input = "sensitivity",
                          ret = c("threshold","sensitivity","specificity"),
                          transpose = FALSE)
  points(1 - pts_s80["specificity"], pts_s80["sensitivity"], pch = 19, col = "#ef4444")
  text(1 - pts_s80["specificity"], pts_s80["sensitivity"], labels = "Sens≥0.80", pos = 4, col = "#ef4444", cex = 0.9)
  dev.off()

  # Sensitivity/Specificity vs threshold curves
  cc <- as.data.frame(pROC::coords(roc_fit, "all",
                                   ret = c("threshold","sensitivity","specificity"),
                                   transpose = FALSE))
  cc <- cc[is.finite(cc$threshold), ]
  p_ss <- ggplot(cc, aes(threshold)) +
    geom_line(aes(y = sensitivity, color = "Sensitivity")) +
    geom_line(aes(y = specificity, color = "Specificity")) +
    scale_color_manual(values = c("Sensitivity"="#ef4444","Specificity"="#1d4ed8")) +
    labs(title = "Sensitivity/Specificity vs threshold", x = expression(theta~"threshold"), y = "Rate", color = "")
  ggsave("outputs/PhaseC_final/fig_sens_spec_vs_threshold.png", p_ss, width = 7.0, height = 4.2, dpi = 200)
}

# 7) Scoring helper (unchanged)
scoring_helper <- function(new_df){
  # Returns EAP theta and SE for new data
  items_order <- rownames(coef(mod, simplify=TRUE)$items)
  to_num <- function(x) {
    if (is.factor(x)) as.numeric(as.character(x))
    else if (inherits(x, "haven_labelled")) as.numeric(as.character(haven::as_factor(x)))
    else as.numeric(x)
  }
  X <- as.data.frame(lapply(new_df[, items_order, drop=FALSE], to_num))
  out <- fscores(mod, method = "EAP", full.scores.SE = TRUE, response.pattern = X)
  data.frame(theta = out[, "F1"], se = out[, "SE_F1"])
}
dput(scoring_helper, file = "outputs/PhaseC_final/scoring_helper.R")

# 8) One-page scoring guide (update item list as needed)
guide_lines <- c(
  "Short-form DASS (15 items): dQ7A,dQ10D,dQ13D,dQ14S,dQ16D,dQ17D,dQ18S,dQ19A,dQ20A,dQ21D,dQ1S,dQ9A,dQ11S,dQ12S,dQ15A",
  "- Model: GRM; Scores: EAP theta with SE; higher theta = higher distress",
  "- Test information peaks in θ≈0–1.5 (screening range), providing high precision where decisions are made",
  "- Use ROC cut-score(s) from annotated plots/tables: Youden (balanced) and Sens≥0.80 (sensitivity-prioritized)",
  "- Dashboards: report mean θ, % elevated (by cut), and calibrated latent score if required"
)
writeLines(guide_lines, "outputs/PhaseC_final/short_form_scoring_guide.txt")

cat("Phase C4: fixed visuals and deliverables written to outputs/PhaseC_final.\n")
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# Phase C4: fixed visuals and deliverables written to outputs/PhaseC_final.

# %%
library(readr); library(dplyr); library(ggplot2); library(broom)

scores <- readr::read_csv("outputs/PhaseC_prep/final_grm_scores.csv", show_col_types = FALSE)
if (!"theta" %in% names(scores) && "theta15" %in% names(scores)) scores <- rename(scores, theta = theta15)
scores <- scores |> mutate(id = trimws(as.character(id)))

gdist <- readr::read_csv("outputs/Phase3/latent_general_distress.csv", show_col_types = FALSE) |>
         mutate(id = trimws(as.character(id)))

link_df <- inner_join(scores, gdist, by = "id") |> filter(is.finite(theta), is.finite(gdist))
stopifnot(nrow(link_df) > 10)

mdl_link <- lm(gdist ~ theta, data = link_df)
saveRDS(mdl_link, "outputs/PhaseC_final/link_theta_to_sem.rds")
readr::write_csv(broom::tidy(mdl_link), "outputs/PhaseC_final/link_lm_summary.csv")

scores$theta_cal <- as.numeric(predict(mdl_link, newdata = scores))
readr::write_csv(scores, "outputs/PhaseC_prep/final_grm_scores_calibrated.csv")

p_cal <- ggplot(scores |> filter(is.finite(theta), is.finite(theta_cal)),
                aes(theta, theta_cal)) +
  geom_point(alpha = 0.25, size = 1.2, color = "#0f766e") +
  geom_smooth(method = "lm", se = TRUE, color = "#0ea5e9") +
  labs(title = "Calibration: short-form theta to SEM latent",
       x = "Short-form theta (EAP)", y = "Calibrated latent (SEM scale)") +
  theme_minimal(11)
ggsave("outputs/PhaseC_final/fig_calibration_theta.png", p_cal, width = 6.4, height = 4.5, dpi = 200,bg="white")
# Out:
# `geom_smooth()` using formula = 'y ~ x'

# %%
#final phase C

# %%
# STAGE A: Freeze psychometrics for thesis
library(mirt); library(readr); library(dplyr); library(ggplot2); library(tidyr)

dir.create("thesis/PhaseC_A_psychometrics/figs", recursive = TRUE, showWarnings = FALSE)

# Load reduced model and optional baseline model
mod15 <- readRDS("outputs/PhaseC_final15/mod15.rds")            # existing 15-item model
base_path <- "outputs/PhaseC_drop_packet/test_info_base.csv"    # optional TIF base (21-item)
reduced_path <- "outputs/PhaseC_drop_packet/test_info_reduced_15.csv"

# A1) Item parameters table (a, b_k)
pars15 <- coef(mod15, IRTpars = TRUE, simplify = TRUE)$items |> as.data.frame()
pars15$item <- rownames(pars15)
keep_cols <- c("item","a", grep("^b\\d+", names(pars15), value = TRUE))
pars_tbl <- pars15[, keep_cols, drop = TRUE]
write_csv(pars_tbl, "thesis/PhaseC_A_psychometrics/item_parameters_15.csv")

# A2) Item trace and item information facets (to files)
png("thesis/PhaseC_A_psychometrics/figs/item_traces_facet_15.png", width = 1600, height = 1200, res = 180)
plot(mod15, type = "trace", facet_items = TRUE)
dev.off()

png("thesis/PhaseC_A_psychometrics/figs/item_info_facets_15.png", width = 1600, height = 1200, res = 180)
plot(mod15, type = "infotrace", facet_items = TRUE)
dev.off()

# A3) Q3 residuals: heatmap and top pairs
q3 <- residuals(mod15, type = "Q3")
q3_df <- reshape2::melt(q3, varnames = c("lhs","rhs"), value.name = "Q3") |> dplyr::filter(lhs != rhs)
p_q3 <- ggplot(q3_df, aes(lhs, rhs, fill = Q3)) +
  geom_tile() + scale_fill_viridis_c() + coord_equal() +
  theme(axis.text.x = element_text(angle = 90, hjust = 1)) +
  labs(title = "Q3 residuals heatmap (15-item GRM)", x = "Item", y = "Item")
ggsave("thesis/PhaseC_A_psychometrics/figs/q3_heatmap_15.png", p_q3, width = 11, height = 9, dpi = 200)

q3_pairs <- q3_df |> filter(as.character(lhs) < as.character(rhs)) |> arrange(desc(Q3))
write_csv(head(q3_pairs, 100), "thesis/PhaseC_A_psychometrics/top_Q3_pairs_15.csv")

# A4) TIF/reliability overlays (reduced vs baseline) with shaded screening band
band_lo <- 0.0; band_hi <- 2.0
if (file.exists(reduced_path)) {
  red <- read_csv(reduced_path, show_col_types = FALSE) |> mutate(model = "Reduced-15")
} else {
  Theta <- seq(-3,3,by=.1); TI <- testinfo(mod15, Theta); REL <- TI/(TI+1)
  red <- data.frame(theta=Theta, test_info=TI, reliability=REL, model="Reduced-15")
  write_csv(red[,c("theta","test_info","reliability")], "thesis/PhaseC_A_psychometrics/test_info_reduced_15.csv")
}
if (file.exists(base_path)) {
  base <- read_csv(base_path, show_col_types = FALSE) |> mutate(model = "Baseline-21")
} else {
  base <- NULL
}
tif_df <- if (!is.null(base)) bind_rows(red, base) else red

p_tif <- ggplot(tif_df, aes(theta, test_info, color = model)) +
  annotate("rect", xmin = band_lo, xmax = band_hi, ymin = -Inf, ymax = Inf,
           fill = "#ecfeff", alpha = 0.5) +
  geom_line(size = 1.1) +
  labs(title = "Test information: Reduced-15 vs Baseline-21",
       x = expression(theta), y = "Test information") +
  theme(legend.position = "bottom")
ggsave("thesis/PhaseC_A_psychometrics/figs/tif_overlay.png", p_tif, width = 9, height = 6, dpi = 200)

p_rel <- ggplot(tif_df, aes(theta, reliability, color = model)) +
  annotate("rect", xmin = band_lo, xmax = band_hi, ymin = -Inf, ymax = Inf,
           fill = "#ecfeff", alpha = 0.5) +
  geom_line(size = 1.1) +
  geom_hline(yintercept = 0.80, linetype = 2) +
  labs(title = "Reliability across theta", x = expression(theta), y = "Reliability") +
  theme(legend.position = "bottom")
ggsave("thesis/PhaseC_A_psychometrics/figs/reliability_overlay.png", p_rel, width = 9, height = 6, dpi = 200)
# Out:
# Q3 summary statistics:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  -0.248  -0.110  -0.062  -0.055  -0.007   0.214
#
#         dQ7A  dQ10D  dQ13D  dQ14S  dQ16D  dQ17D  dQ18S  dQ19A  dQ20A  dQ21D   dQ1S   dQ9A  dQ11S  dQ12S  dQ15A
# dQ7A   1.000 -0.104 -0.035  0.111 -0.022 -0.164  0.094  0.058 -0.048 -0.202 -0.004  0.059 -0.093 -0.085  0.038
# dQ10D -0.104  1.000 -0.126 -0.062  0.061  0.066 -0.248 -0.186 -0.128  0.080 -0.065 -0.073 -0.028 -0.044 -0.197
# dQ13D -0.035 -0.126  1.000  0.017 -0.065 -0.113  0.089 -0.078 -0.165 -0.104 -0.053 -0.131 -0.078 -0.028 -0.091
# dQ14S  0.111 -0.062  0.017  1.000 -0.023 -0.180  0.097 -0.007 -0.100 -0.122  0.056 -0.015  0.000 -0.119 -0.021
# dQ16D -0.022  0.061 -0.065 -0.023  1.000  0.037 -0.119 -0.106 -0.154 -0.018 -0.066 -0.103 -0.110 -0.075 -0.146
# dQ17D -0.164  0.066 -0.113 -0.180  0.037  1.000 -0.083 -0.164 -0.072  0.214 -0.089 -0.095 -0.125 -0.042 -0.231
# ...

# %%
# STAGE B: Calibration to Phase-3 SEM latent
library(readr); library(dplyr); library(ggplot2); library(lavaan)

dir.create("thesis/PhaseC_B_calibration", recursive = TRUE, showWarnings = FALSE)

# B1) Load short-form scores; ensure theta column exists
scores <- read_csv("outputs/PhaseC_prep/final_grm_scores.csv", show_col_types = FALSE)
if (!"theta" %in% names(scores) && "theta15" %in% names(scores)) scores <- rename(scores, theta = theta15)
scores <- scores |> mutate(id = trimws(as.character(id)))

# B2) Build Phase-3 calibration target (choose one data source)
# Option 1: From saved lavaan object (preferred to ensure row alignment)
# fit_core <- readRDS("outputs/SEM/final/fit_core_object.rds")  # if saved earlier
# If fit_core present:
# idx_used <- lavInspect(fit_core, "case.idx")
# fs_mat   <- lavPredict(fit_core, type = "lv", label = TRUE)
# fs_df    <- as.data.frame(fs_mat)
# gdist    <- rowMeans(scale(fs_df[, c("Dep","Anx","Str")]), na.rm = TRUE)
# ids      <- as.character(dat$id)[idx_used]
# sem_cal  <- data.frame(id = ids, gdist = as.numeric(gdist))

# Option 2: From CSV created in Phase 3 (already prepared previously)
sem_cal <- read_csv("outputs/Phase3/latent_general_distress.csv", show_col_types = FALSE) |>
           mutate(id = trimws(as.character(id)))
stopifnot(all(c("id","gdist") %in% names(sem_cal)))

# B3) Fit linear linker and export
link_df <- inner_join(scores, sem_cal, by = "id") |> filter(is.finite(theta), is.finite(gdist))
mdl_link <- lm(gdist ~ theta, data = link_df)

# Save coefficients and model
saveRDS(mdl_link, "thesis/PhaseC_B_calibration/link_theta_to_sem.rds")
readr::write_csv(broom::tidy(mdl_link), "thesis/PhaseC_B_calibration/link_lm_summary.csv")

# Predict calibrated latent for all records (for appendix reproducibility)
scores$theta_cal <- as.numeric(predict(mdl_link, newdata = scores))
write_csv(scores, "thesis/PhaseC_B_calibration/scores_with_theta_cal.csv")

# B4) Calibration plot (for thesis main text)
p_cal <- ggplot(scores |> filter(is.finite(theta), is.finite(theta_cal)),
                aes(theta, theta_cal)) +
  geom_point(alpha = 0.25, size = 1.2, color = "#0f766e") +
  geom_smooth(method = "lm", se = TRUE, color = "#0ea5e9") +
  labs(title = "Calibration: short-form theta to SEM latent",
       x = "Short-form theta (EAP)", y = "Calibrated latent (SEM scale)") +
  theme_minimal(11)
ggsave("thesis/PhaseC_B_calibration/fig_calibration_theta.png", p_cal, width = 6.4, height = 4.5, dpi = 200)
# Out:
# This is lavaan 0.6-19
# lavaan is FREE software! Please report any bugs.
# `geom_smooth()` using formula = 'y ~ x'

# %%
#stage C: ROC vs criterion (high-distress cluster or latent > +1 SD)
library(readr); library(dplyr); library(ggplot2); library(pROC)

dir.create("thesis/PhaseC_C_roc", recursive = TRUE, showWarnings = FALSE)

# Scores (calibrated, if available)
scores <- readr::read_csv("outputs/PhaseC_prep/final_grm_scores_calibrated.csv", show_col_types = FALSE)
if (!"theta" %in% names(scores) && "theta15" %in% names(scores)) scores <- dplyr::rename(scores, theta = theta15)
scores <- scores %>% mutate(id = trimws(as.character(id)))

# Criterion (final two-cluster labels; C2 = high distress)
crit_raw <- readr::read_csv("outputs/Phase4/labels_k2_final.csv", show_col_types = FALSE)
crit <- crit_raw %>%
  transmute(
    id = trimws(as.character(id)),
    high_distress = ifelse(cluster == "C2", 1L,
                      ifelse(cluster == "C1", 0L, NA_integer_))
  ) %>%
  filter(!is.na(id), !is.na(high_distress))

# Join and filter
df <- scores %>%
  inner_join(crit, by = "id") %>%
  filter(is.finite(theta), !is.na(high_distress))

stopifnot(nrow(df) > 10, length(unique(df$high_distress)) == 2)

# Save analysis set (reproducibility)
readr::write_csv(df, "thesis/PhaseC_C_roc/roc_analysis_set.csv")

# First pass ROC to check direction
roc1 <- pROC::roc(response = df$high_distress, predictor = df$theta, quiet = TRUE, direction = ">")
auc1 <- as.numeric(pROC::auc(roc1))

# Final direction and ROC
direction_final <- if (auc1 < 0.5) "<" else ">"
roc_obj <- pROC::roc(response = df$high_distress, predictor = df$theta, quiet = TRUE, direction = direction_final)
auc_ci  <- pROC::ci.auc(roc_obj)

# Operating points
best_y <- pROC::coords(roc_obj, x = "best", best.method = "youden",
                       ret = c("threshold","sensitivity","specificity"), transpose = FALSE)
sens80 <- pROC::coords(roc_obj, x = 0.80, input = "sensitivity",
                       ret = c("threshold","sensitivity","specificity"), transpose = FALSE)

# Scalars
y_thr  <- as.numeric(best_y[["threshold"]]); y_sens <- as.numeric(best_y[["sensitivity"]]); y_spec <- as.numeric(best_y[["specificity"]])
s_thr  <- as.numeric(sens80[["threshold"]]); s_sens <- as.numeric(sens80[["sensitivity"]]); s_spec <- as.numeric(sens80[["specificity"]])

# Prevalence and predictive values
prev    <- mean(df$high_distress)
ppv_fun <- function(se, sp, pr) (se*pr)/((se*pr) + ((1-sp)*(1-pr)))
npv_fun <- function(se, sp, pr) (sp*(1-pr))/(((1-se)*pr) + (sp*(1-pr)))

cuts <- dplyr::bind_rows(
  tibble::tibble(cut_name = "Youden",    threshold = y_thr, sensitivity = y_sens, specificity = y_spec),
  tibble::tibble(cut_name = "Sens>=0.80", threshold = s_thr, sensitivity = s_sens, specificity = s_spec)
) %>%
  mutate(prevalence = prev,
         PPV = ppv_fun(sensitivity, specificity, prevalence),
         NPV = npv_fun(sensitivity, specificity, prevalence),
         roc_direction = direction_final)

readr::write_csv(cuts, "thesis/PhaseC_C_roc/roc_operating_points.csv")

# Annotated ROC figure
png("thesis/PhaseC_C_roc/fig_ROC_annotated.png", width = 900, height = 650, res = 140)
plot(roc_obj, print.auc = TRUE, col = "#059669",
     main = sprintf("ROC: theta vs cluster (AUC=%.3f; 95%% CI %.3f–%.3f) dir=%s",
                    as.numeric(auc_ci[4]), as.numeric(auc_ci[5]), as.numeric(auc_ci[6]), direction_final))
abline(0,1,lty=2,col="grey60")
points(1 - y_spec, y_sens, pch = 19, col = "#1d4ed8"); text(1 - y_spec, y_sens, "Youden", pos = 4, col = "#1d4ed8", cex = 0.9)
points(1 - s_spec, s_sens, pch = 19, col = "#ef4444"); text(1 - s_spec, s_sens, "Sens≥0.80", pos = 4, col = "#ef4444", cex = 0.9)
dev.off()

# Sensitivity/Specificity vs threshold
cc <- as.data.frame(pROC::coords(roc_obj, "all",
                                 ret = c("threshold","sensitivity","specificity"),
                                 transpose = FALSE))
cc <- cc[is.finite(cc$threshold), ]
p_ss <- ggplot(cc, aes(threshold)) +
  geom_line(aes(y = sensitivity, color = "Sensitivity")) +
  geom_line(aes(y = specificity, color = "Specificity")) +
  scale_color_manual(values = c("Sensitivity"="#ef4444","Specificity"="#1d4ed8")) +
  labs(title = "Sensitivity/Specificity vs theta threshold", x = expression(theta), y = "Rate", color = "")
ggsave("thesis/PhaseC_C_roc/fig_sens_spec_vs_threshold.png", p_ss, width = 7.0, height = 4.2, dpi = 200)

cat(sprintf("Final AUC = %.3f (95%% CI %.3f–%.3f), direction = %s; prevalence = %.3f\nYouden thr=%.3f, Sens=%.2f, Spec=%.2f | Sens80 thr=%.3f, Sens=%.2f, Spec=%.2f\n",
            as.numeric(auc_ci[4]), as.numeric(auc_ci[5]), as.numeric(auc_ci[6]), direction_final, prev,
            y_thr, y_sens, y_spec, s_thr, s_sens, s_spec))
# Out:
# Final AUC = NA (95% CI NA–NA), direction = <; prevalence = 0.485
# Youden thr=-0.055, Sens=0.89, Spec=0.85 | Sens80 thr=NA, Sens=0.80, Spec=0.90

# %%
# =========================
# Stage D (thesis-friendly): DIF screen lite without MG
# =========================
# Fits separate single-group GRMs by group, compares item parameters (a, b_k)
# using bootstrap CIs and standardized differences; complements with S-X2 item fit.

library(mirt)
library(readr)
library(dplyr)
library(tidyr)
library(purrr)

outdir <- "thesis/PhaseC_D_dif_lite"
dir.create(outdir, recursive = TRUE, showWarnings = FALSE)

# A) Load items and IDs aligned with GRM
inp    <- readRDS("outputs/PhaseC_prep/phaseC_inputs.rds")
keep15 <- readLines("outputs/PhaseC_drop_packet/shortform_15_items.txt")
dat_all <- as.data.frame(inp$resp_dass_num)
stopifnot(all(keep15 %in% names(dat_all)))
dat15 <- dat_all[, keep15, drop = FALSE]
ids   <- tibble::tibble(id = as.character(inp$id))

# B) Recover groups (Option 1)
dem <- readRDS("data/processed/analysis_phase1_ordered.rds") |>
  mutate(
    id = as.character(id),
    gender = haven::as_factor(gender, levels = "labels"),
    academic_year = haven::as_factor(academic_year, levels = "labels")
  ) |>
  transmute(id,
            gender = as.character(gender),
            academic_year = as.character(academic_year))

grp <- ids %>% left_join(dem, by = "id")

# C) Clean rows and groups (Gender example)
row_all_na <- apply(dat15, 1, function(x) all(is.na(x)))
dat15_  <- dat15[!row_all_na, , drop = FALSE]
grp_    <- grp[!row_all_na, , drop = FALSE]

grp_$gender[is.na(grp_$gender)] <- "Missing"
gender <- grp_$gender
gender <- factor(gender)
# Keep only two largest valid groups (Male/Female), drop Missing
tab_g <- sort(table(gender), decreasing = TRUE)
lvl_g <- names(tab_g)[names(tab_g) %in% c("Male","Female")]
if (length(lvl_g) < 2) {
  lvl_g <- names(tab_g)[1:2]
}
keep_g <- gender %in% lvl_g & gender != "Missing"
dat_g  <- dat15_[keep_g, , drop = FALSE]
gender2 <- droplevels(gender[keep_g])

write_csv(as.data.frame(table(gender2)), file.path(outdir, "counts_gender_final.csv"))

# D) Function to fit single-group GRM with bootstrap CIs for item parameters
fit_grm_boot <- function(data_items, B = 200, seed = 20250913){
  set.seed(seed)
  mod <- mirt(data_items, 1, itemtype = "graded", method = "EM", SE = TRUE,
              technical = list(NCYCLES = 1500))
  pars <- as.data.frame(coef(mod, IRTpars = TRUE, simplify = TRUE)$items)
  pars$item <- rownames(coef(mod, IRTpars = TRUE, simplify = TRUE)$items)
  # Bootstrap: nonparametric resampling of rows
  n <- nrow(data_items)
  boots <- vector("list", B)
  for (b in seq_len(B)) {
    idx <- sample.int(n, n, replace = TRUE)
    mb <- try(mirt(data_items[idx, , drop = FALSE], 1, itemtype = "graded",
                   method = "EM", SE = FALSE, technical = list(NCYCLES = 800)),
              silent = TRUE)
    if (inherits(mb, "SingleGroupClass")) {
      pb <- as.data.frame(coef(mb, IRTpars = TRUE, simplify = TRUE)$items)
      pb$item <- rownames(coef(mb, IRTpars = TRUE, simplify = TRUE)$items)
      boots[[b]] <- pb
    }
  }
  boots <- boots[!vapply(boots, is.null, logical(1))]
  if (length(boots) > 20) {
    boot_df <- dplyr::bind_rows(boots, .id = "boot_id")
    # Compute 95% CIs per parameter per item
    qfun <- function(v) quantile(v, probs = c(.025,.975), na.rm = TRUE)
    ci <- boot_df %>%
      group_by(item) %>%
      summarise(across(where(is.numeric),
                       ~{qq <- qfun(.x); tibble(lo = qq[1], hi = qq[2])},
                       .names = "{.col}_{.fn}"), .groups="drop")
  } else {
    ci <- NULL
  }
  list(model = mod, pars = pars, ci = ci)
}

# E) Fit by gender groups
idx_M <- which(gender2 == levels(gender2)[1])
idx_F <- which(gender2 == levels(gender2)[2])

fit_M <- fit_grm_boot(dat_g[idx_M, , drop = FALSE], B = 150)
fit_F <- fit_grm_boot(dat_g[idx_F, , drop = FALSE], B = 150)

# F) Merge parameters and compute standardized diffs
merge_pars <- function(p1, p2, g1, g2){
  p1s <- p1$pars; p1s$group <- g1
  p2s <- p2$pars; p2s$group <- g2
  allp <- bind_rows(p1s, p2s)
  # Keep a and b1..bk columns
  bcols <- grep("^b\\d+", names(allp), value = TRUE)
  keepc <- c("item","group","a", bcols)
  allp <- allp[, keepc, drop = FALSE]
  # Wide
  w <- pivot_wider(allp, id_cols = item, names_from = group,
                   values_from = c(a, all_of(bcols)),
                   names_sep = "__")
  # Diffs (g2 - g1)
  diffs <- w
  gnames <- c(g1, g2)
  # Compute standardized diff using pooled SD from bootstrap if available, otherwise plain diff
  std_df <- diffs
  for (nm in c("a", bcols)) {
    c1 <- paste0(nm, "__", g1); c2 <- paste0(nm, "__", g2)
    std_df[[paste0(nm, "_diff")]] <- std_df[[c2]] - std_df[[c1]]
  }
  std_df
}

g1 <- levels(gender2)[1]; g2 <- levels(gender2)[2]
cmp <- merge_pars(fit_M, fit_F, g1, g2)

# Simple flagging heuristics (thesis screen): |Δa| >= 0.20 or any |Δb_k| >= 0.25
bcols <- grep("^b\\d+_diff$", names(cmp), value = TRUE)
cmp$flag <- with(cmp, ifelse(abs(a_diff) >= 0.20 | apply(abs(cmp[, bcols, drop = FALSE]), 1, max, na.rm = TRUE) >= 0.25, "FLAG","OK"))

write_csv(cmp, file.path(outdir, "dif_gender_param_compare.csv"))

# G) Group-wise item fit (S-X2) as supporting evidence
itfit_M <- tryCatch({af <- itemfit(fit_M$model); df <- as.data.frame(af); df$item <- rownames(af); df$group <- g1; df}, error = function(e) NULL)
itfit_F <- tryCatch({af <- itemfit(fit_F$model); df <- as.data.frame(af); df$item <- rownames(af); df$group <- g2; df}, error = function(e) NULL)
itfit <- bind_rows(itfit_M, itfit_F)
if (nrow(itfit)) write_csv(itfit, file.path(outdir, "dif_gender_itemfit.csv"))

# H) Summary for appendix
nflag <- sum(cmp$flag == "FLAG", na.rm = TRUE)
max_da <- max(abs(cmp$a_diff), na.rm = TRUE)
max_db <- max(apply(abs(cmp[, bcols, drop = FALSE]), 1, max, na.rm = TRUE))
summ <- c(
  sprintf("Gender DIF-lite: groups=%s vs %s; flags %d/%d (|Δa|>=0.20 or |Δb|>=0.25).", g1, g2, nflag, nrow(cmp)),
  sprintf("Max |Δa|=%.3f; Max |Δb_k|=%.3f.", max_da, max_db),
  "See dif_gender_param_compare.csv and dif_gender_itemfit.csv."
)
writeLines(summ, file.path(outdir, "summary_gender.txt"))
cat(paste(summ, collapse = "\n"), "\n")

# I) Optional: Year DIF-lite (repeat after collapsing to two largest non-missing strata)
year <- grp_$academic_year
year <- factor(year)
tab_y <- sort(table(year), decreasing = TRUE)
lvl_y <- names(tab_y)[tab_y > 0 & names(tab_y) != "Missing"]
if (length(lvl_y) >= 2) {
  lvl_y <- lvl_y[1:2]
  keep_y <- year %in% lvl_y
  dat_y  <- dat15_[keep_y, , drop = FALSE]
  year2  <- droplevels(year[keep_y])
  write_csv(as.data.frame(table(year2)), file.path(outdir, "counts_year_final.csv"))

  idx_A <- which(year2 == levels(year2)[1])
  idx_B <- which(year2 == levels(year2)[2])

  fit_A <- fit_grm_boot(dat_y[idx_A, , drop = FALSE], B = 120)
  fit_B <- fit_grm_boot(dat_y[idx_B, , drop = FALSE], B = 120)

  cmp_y <- merge_pars(fit_A, fit_B, levels(year2)[1], levels(year2)[2])
  bcols_y <- grep("^b\\d+_diff$", names(cmp_y), value = TRUE)
  cmp_y$flag <- with(cmp_y, ifelse(abs(a_diff) >= 0.20 | apply(abs(cmp_y[, bcols_y, drop = FALSE]), 1, max, na.rm = TRUE) >= 0.25, "FLAG","OK"))
  write_csv(cmp_y, file.path(outdir, "dif_year_param_compare.csv"))

  itfit_A <- tryCatch({af <- itemfit(fit_A$model); df <- as.data.frame(af); df$item <- rownames(af); df$group <- levels(year2)[1]; df}, error = function(e) NULL)
  itfit_B <- tryCatch({af <- itemfit(fit_B$model); df <- as.data.frame(af); df$item <- rownames(af); df$group <- levels(year2)[2]; df}, error = function(e) NULL)
  itfit_y <- bind_rows(itfit_A, itfit_B)
  if (nrow(itfit_y)) write_csv(itfit_y, file.path(outdir, "dif_year_itemfit.csv"))

  nflag_y <- sum(cmp_y$flag == "FLAG", na.rm = TRUE)
  max_da_y <- max(abs(cmp_y$a_diff), na.rm = TRUE)
  max_db_y <- max(apply(abs(cmp_y[, bcols_y, drop = FALSE]), 1, max, na.rm = TRUE))
  summ_y <- c(
    sprintf("Year DIF-lite: groups=%s vs %s; flags %d/%d.", levels(year2)[1], levels(year2)[2], nflag_y, nrow(cmp_y)),
    sprintf("Max |Δa|=%.3f; Max |Δb_k|=%.3f.", max_da_y, max_db_y),
    "See dif_year_param_compare.csv and dif_year_itemfit.csv."
  )
  writeLines(summ_y, file.path(outdir, "summary_year.txt")); cat(paste(summ_y, collapse = "\n"), "\n")
} else {
  writeLines("Year DIF-lite skipped: <2 usable strata after cleaning.", file.path(outdir, "summary_year.txt"))
}

# J) README for appendix
writeLines(c(
  "DIF-lite outputs (no MG identification required):",
  "- counts_gender_final.csv, dif_gender_param_compare.csv, dif_gender_itemfit.csv, summary_gender.txt",
  "- counts_year_final.csv, dif_year_param_compare.csv, dif_year_itemfit.csv, summary_year.txt (if run)"
), file.path(outdir, "README_outputs.txt"))
# Out:
# Iteration: 58, Log-Lik: -7773.037, Max-Change: 0.00008
#
# Calculating information matrix...
# Iteration: 28, Log-Lik: -7580.171, Max-Change: 0.00009
# Iteration: 59, Log-Lik: -7666.101, Max-Change: 0.00009
# Iteration: 21, Log-Lik: -7753.655, Max-Change: 0.00007
# Iteration: 32, Log-Lik: -7796.212, Max-Change: 0.00009
# Iteration: 30, Log-Lik: -7747.059, Max-Change: 0.00007
# Iteration: 58, Log-Lik: -7794.612, Max-Change: 0.00010
# Iteration: 55, Log-Lik: -7810.738, Max-Change: 0.00010
# Iteration: 64, Log-Lik: -7746.308, Max-Change: 0.00010
# Iteration: 47, Log-Lik: -7775.610, Max-Change: 0.00009
# Iteration: 64, Log-Lik: -7750.385, Max-Change: 0.00010
# Iteration: 52, Log-Lik: -7644.133, Max-Change: 0.00009
# Iteration: 52, Log-Lik: -7705.624, Max-Change: 0.00009
# Iteration: 46, Log-Lik: -7826.245, Max-Change: 0.00010
# Iteration: 41, Log-Lik: -7771.022, Max-Change: 0.00009
# Iteration: 42, Log-Lik: -7720.052, Max-Change: 0.00009
# ...

# %%
# ================
# Stage 5: Write-up exhibits (thesis)
# ================
library(readr); library(dplyr); library(ggplot2); library(stringr)

dir.create("thesis/Stage5_writeup/figs", recursive = TRUE, showWarnings = FALSE)
dir.create("thesis/Stage5_writeup/tables", recursive = TRUE, showWarnings = FALSE)

# 1) Calibration summary table (coef, SE, p, R2)
cal_sum_path <- "outputs/PhaseC_final/link_lm_summary.csv"
if (!file.exists(cal_sum_path)) cal_sum_path <- "thesis/PhaseC_B_calibration/link_lm_summary.csv"
cal <- readr::read_csv(cal_sum_path, show_col_types = FALSE)
# Add R2 if present in a model RDS
r2 <- NA_real_
if (file.exists("outputs/PhaseC_final/link_theta_to_sem.rds")) {
  mdl <- readRDS("outputs/PhaseC_final/link_theta_to_sem.rds")
  r2 <- summary(mdl)$r.squared
}
cal_out <- cal %>%
  transmute(term, estimate = round(estimate, 3), std_error = round(std.error, 3),
            statistic = round(statistic, 2), p_value = signif(p.value, 3)) %>%
  mutate(R2_model = ifelse(row_number() == 1, sprintf("%.3f", r2), ""))
readr::write_csv(cal_out, "thesis/Stage5_writeup/tables/calibration_summary.csv")

# 2) Operating points table (Youden, Sens>=0.80)
roc_tbl_path <- "outputs/PhaseC_prep/roc_cut_youden.csv"
roc_op_path  <- "thesis/PhaseC_C_roc/roc_operating_points.csv"
ops <- if (file.exists(roc_op_path)) read_csv(roc_op_path, show_col_types = FALSE) else {
  if (file.exists(roc_tbl_path)) read_csv(roc_tbl_path, show_col_types = FALSE) else NULL
}
if (!is.null(ops)) {
  ops_out <- ops %>%
    mutate(across(c(threshold, sensitivity, specificity, prevalence, PPV, NPV), ~round(.x, 3)))
  readr::write_csv(ops_out, "thesis/Stage5_writeup/tables/operating_points.csv")
}

# 3) Minimal item table (a and thresholds)
pars_path <- "outputs/PhaseC_final/table_item_parameters.csv"
if (!file.exists(pars_path)) pars_path <- "outputs/PhaseC_final15/item_parameters_15.csv"
pars <- readr::read_csv(pars_path, show_col_types = FALSE)
item_tbl <- pars %>%
  select(item, a, starts_with("b")) %>%
  mutate(across(-item, ~round(.x, 3)))
readr::write_csv(item_tbl, "thesis/Stage5_writeup/tables/item_parameters_min.csv")

# 4) Copy finalized figures to thesis/figs with standard names and DPI
copy_fig <- function(src, dest_name) {
  if (file.exists(src)) file.copy(src, file.path("thesis/Stage5_writeup/figs", dest_name), overwrite = TRUE)
}
# From earlier stages (adjust paths if stored differently)
copy_fig("outputs/PhaseC_final/fig_test_information_band.png",  "fig_tif_band.png")
copy_fig("outputs/PhaseC_final/fig_item_discrimination.png",   "fig_discrimination.png")
copy_fig("outputs/PhaseC_final/fig_trace_curves_items_1to6.png","fig_traces_subset.png")
copy_fig("outputs/PhaseC_final/fig_ROC_annotated.png",         "fig_ROC_annotated.png")
copy_fig("outputs/PhaseC_final/fig_sens_spec_vs_threshold.png","fig_sens_spec_vs_threshold.png")
copy_fig("thesis/PhaseC_B_calibration/fig_calibration_theta.png","fig_calibration_theta.png")
# Alternative sources from PhaseC_final15
alt <- list(
  c("outputs/PhaseC_final15/figs/item_traces_facet_15.png", "fig_traces_faceted.png"),
  c("outputs/PhaseC_final15/figs/item_info_curves_15.png",  "fig_item_info_facets.png"),
  c("outputs/PhaseC_final15/figs/q3_heatmap_15.png",        "fig_q3_heatmap.png"),
  c("outputs/PhaseC_final15/figs/tif_reduced_vs_base.png",  "fig_tif_overlay.png"),
  c("outputs/PhaseC_final15/figs/reliability_reduced_vs_base.png","fig_reliability_overlay.png"),
  c("outputs/PhaseC_final15/figs/theta_distribution_15.png","fig_theta_distribution.png"),
  c("outputs/PhaseC_final15/figs/rawsum_vs_theta_15.png",   "fig_rawsum_vs_theta.png")
)
invisible(lapply(alt, function(z) copy_fig(z[21], z[22])))

# 5) Quick exhibit index for manuscript
exhibit_index <- tibble::tibble(
  section = c("Psychometrics","Psychometrics","Calibration","ROC"),
  figure  = c("fig_tif_overlay.png / fig_tif_band.png",
              "fig_traces_faceted.png / fig_item_info_facets.png / fig_q3_heatmap.png",
              "fig_calibration_theta.png",
              "fig_ROC_annotated.png / fig_sens_spec_vs_threshold.png"),
  table   = c("item_parameters_min.csv", "—", "calibration_summary.csv", "operating_points.csv")
)
readr::write_csv(exhibit_index, "thesis/Stage5_writeup/exhibit_index.csv")

cat("Stage 5 write-up exhibits prepared in thesis/Stage5_writeup/\n")
# Out:
# Stage 5 write-up exhibits prepared in thesis/Stage5_writeup/

# %%
# ================
# Stage 6: Reproducibility bundle (thesis)
# ================
library(readr); library(dplyr); library(stringr); library(fs)

root_out <- "thesis/Stage6_repro"
dir_create(root_out)
dir_create(path(root_out, "code"))
dir_create(path(root_out, "data"))   # pointers/readme only if raw data are restricted
dir_create(path(root_out, "outputs"))
dir_create(path(root_out, "figs"))

# 1) Copy core outputs and figures
copy_safe <- function(src, dest_dir = path(root_out, "outputs")) {
  if (file.exists(src)) file_copy(src, dest_dir, overwrite = TRUE)
}

# Core outputs used in manuscript
core_files <- c(
  # Psychometrics
  "outputs/PhaseC_final15/item_parameters_15.csv",
  "outputs/PhaseC_final15/test_info_reduced_15.csv",
  "outputs/PhaseC_drop_packet/test_info_base.csv",
  "thesis/Stage5_writeup/tables/item_parameters_min.csv",
  "thesis/Stage5_writeup/tables/calibration_summary.csv",
  "thesis/Stage5_writeup/tables/operating_points.csv",
  # Scores and mapping
  "outputs/PhaseC_final15/scores_15.csv",
  "outputs/PhaseC_final15/lookup_rawsum_to_theta.csv",
  "outputs/PhaseC_final15/rawsum_to_theta_map.rds",
  # Calibration
  "outputs/PhaseC_final/link_lm_summary.csv",
  "outputs/PhaseC_final/link_theta_to_sem.rds",
  "thesis/PhaseC_B_calibration/scores_with_theta_cal.csv",
  # ROC
  "thesis/PhaseC_C_roc/roc_operating_points.csv",
  "thesis/PhaseC_C_roc/roc_analysis_set.csv"
)
invisible(lapply(core_files, copy_safe))

# Figures
fig_files <- c(
  "thesis/Stage5_writeup/figs/fig_tif_overlay.png",
  "thesis/Stage5_writeup/figs/fig_tif_band.png",
  "thesis/Stage5_writeup/figs/fig_traces_faceted.png",
  "thesis/Stage5_writeup/figs/fig_item_info_facets.png",
  "thesis/Stage5_writeup/figs/fig_q3_heatmap.png",
  "thesis/Stage5_writeup/figs/fig_calibration_theta.png",
  "thesis/Stage5_writeup/figs/fig_ROC_annotated.png",
  "thesis/Stage5_writeup/figs/fig_sens_spec_vs_threshold.png"
)
invisible(lapply(fig_files, function(f) if (file_exists(f)) file_copy(f, path(root_out, "figs"), overwrite = TRUE)))

# 2) Main script template to re-create key exhibits
main_script <- '
# Recreate key thesis exhibits (minimal)
library(readr); library(dplyr); library(ggplot2); library(mirt); library(pROC)

# A) Load and plot TIF overlay from saved CSVs
red <- read_csv("outputs/PhaseC_final15/test_info_reduced_15.csv", show_col_types = FALSE) %>% mutate(model = "Reduced-15")
base <- read_csv("outputs/PhaseC_drop_packet/test_info_base.csv", show_col_types = FALSE) %>% mutate(model = "Baseline-21")
tif_df <- bind_rows(red, base)
band_lo <- 0.0; band_hi <- 2.0
p_tif <- ggplot(tif_df, aes(theta, test_info, color = model)) +
  annotate("rect", xmin = band_lo, xmax = band_hi, ymin = -Inf, ymax = Inf, fill = "#ecfeff", alpha = 0.5) +
  geom_line(size = 1.1) +
  labs(title = "Test information overlay", x = expression(theta), y = "Information") +
  theme(legend.position = "bottom")
ggsave("figs/rep_fig_tif_overlay.png", p_tif, width = 9, height = 6, dpi = 200)

# B) Calibration plot from scores_with_theta_cal
sc <- read_csv("thesis/PhaseC_B_calibration/scores_with_theta_cal.csv", show_col_types = FALSE)
p_cal <- ggplot(sc %>% filter(is.finite(theta), is.finite(theta_cal)), aes(theta, theta_cal)) +
  geom_point(alpha = 0.25, size = 1.2, color = "#0f766e") +
  geom_smooth(method = "lm", se = TRUE, color = "#0ea5e9") +
  labs(title = "Calibration: theta to SEM latent", x = "theta (EAP)", y = "theta_cal") +
  theme_minimal(11)
ggsave("figs/rep_fig_calibration.png", p_cal, width = 6.4, height = 4.5, dpi = 200)

# C) ROC (optional if analysis set available)
if (file.exists("thesis/PhaseC_C_roc/roc_analysis_set.csv")){
  df <- read_csv("thesis/PhaseC_C_roc/roc_analysis_set.csv", show_col_types = FALSE)
  roc_obj <- pROC::roc(response = df$high_distress, predictor = df$theta, quiet = TRUE, direction = ">")
  auc_ci  <- pROC::ci.auc(roc_obj)
  png("figs/rep_fig_ROC.png", width = 900, height = 650, res = 140)
  plot(roc_obj, print.auc = TRUE, col = "#059669",
       main = sprintf("ROC: AUC=%.3f; 95%% CI %.3f–%.3f", as.numeric(auc_ci[22]), as.numeric(auc_ci[21]), as.numeric(auc_ci[23])))
  abline(0,1,lty=2,col="grey60"); dev.off()
}
'
writeLines(main_script, path(root_out, "code", "main_recreate_exhibits.R"))

# 3) README (machine-readable pointers)
readme <- c(
  "# Thesis reproducibility bundle",
  "",
  "Contents:",
  "- code/main_recreate_exhibits.R: minimal script to regenerate core figures from saved CSVs.",
  "- outputs/: CSVs and RDS used in the manuscript (psychometrics, calibration, ROC).",
  "- figs/: thesis figures and regenerated replicas.",
  "",
  "Software:",
  "- R (list versions used in thesis); packages: mirt, pROC, ggplot2, dplyr, readr.",
  "",
  "Run:",
  "1) Open code/main_recreate_exhibits.R and source it.",
  "2) Figures will be written to figs/ with prefix rep_fig_.",
  "",
  "Mapping (exhibits -> files):",
  "- TIF overlay: outputs/PhaseC_final15/test_info_reduced_15.csv, outputs/PhaseC_drop_packet/test_info_base.csv.",
  "- Calibration table: outputs/PhaseC_final/link_lm_summary.csv; plot from thesis/PhaseC_B_calibration/scores_with_theta_cal.csv.",
  "- Operating points: thesis/PhaseC_C_roc/roc_operating_points.csv; annotated ROC in figs/.",
  "",
  "Data availability:",
  "- Person-level raw data are not included; this bundle uses derived CSVs from the thesis pipeline.",
  "- For full re-estimation, see data/ pointers and Phase C scripts in the project.",
  "",
  "Notes:",
  "- PPV/NPV depend on observed prevalence; reported values in operating_points.csv reflect the study prevalence.",
  "- Re-generated figures should match the manuscript within minor rendering differences (fonts, antialiasing)."
)
writeLines(readme, path(root_out, "README.txt"))

cat("Stage 6 reproducibility bundle prepared in thesis/Stage6_repro\n")
# Out:
# Stage 6 reproducibility bundle prepared in thesis/Stage6_repro
